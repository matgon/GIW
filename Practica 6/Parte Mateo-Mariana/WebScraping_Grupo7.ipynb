# %% [markdown]
# ### Práctica de Web Scraping
#
# Se va a considerar una página web de wikipedia donde se encuentra un recopilatorio de las pinturas realizadas por Pedro Pablo Rubens: https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens
#
# En la página aparecen varios apartados, de los cuales se va a procesar aquel denominado "Pintura". En este apartado aparecen un conjunto de tablas clasificadas por diferentes etapas artísticas del pintor. En cada tabla aparecen pinturas junto a información asociada a cada una de ellas.

# %%
from IPython.display import Image
Image(filename='Captura.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7152/3156584547.py in <module>
#       1 from IPython.display import Image
# ----> 2 Image(filename='Captura.png')
#
# ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Captura.png'

# %% [markdown]
# La tabla está formada por 6 columnas: Imagen, Título,Dimensiones, Fechad de creación, Referencia, Colección/localización.
#
# Observa cómo es la estructura de una fila.

# %% [raw]
# <tr>
# <td><a href="/wiki/Archivo:Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg" class="image"><img alt="Peter Paul Rubens - Portrait of a Young Scholar - WGA20349.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/150px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg" decoding="async" width="150" height="237" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/225px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/300px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg 2x" data-file-width="823" data-file-height="1300" /></a>
# </td>
# <td><i>Retrato de hombre, puede ser un arquitecto o un geógrafo</i>
# </td>
# <td><span style="white-space:nowrap">22x15&#160;cm</span>
# </td>
# <td><a href="/wiki/1597" title="1597">1597</a>
# </td>
# <td>Óleo sobre cuero
# </td>
# <td><a rel="nofollow" class="external text" href="http://www.metmuseum.org/art/collection/search/437530?sortBy=Relevance&amp;ft=peter+paul+rubens&amp;offset=0&amp;rpp=20&amp;pos=2">Musée</a>
# </td>
# <td><a href="/wiki/Metropolitan_Museum_of_Art" class="mw-redirect" title="Metropolitan Museum of Art">Metropolitan Museum of Art</a>
# </td></tr>
# <tr>

# %% [markdown]
# Los enlaces a las imágenes se encuentran en el atributo src del elemento __"</img/>"__.En el ejemplo anterior, el valor de src es:
#
# //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/150px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg
#
# Para acceder a la imagen se debe añadir https: delante del valor recuperado:
#
# https://upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/150px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg

# %% [markdown]
# Otra  característica que hay que tener en cuenta es cómo aparecen delimitados las etapas pictóricas:
#
# 1 Pintura
#
#         1.1 Viaje a Italia 1600-1608
#
#         1.2 Retorno a Amberes en 1608
#
#         1.3 Creación de su taller en 1615
#
#         1.4 Départ de Van Dyck en Angleterre en 1620
#
#         1.5 Pinturas de los últimos años
#
#
# El título referido a 1 aparece en la página html en una etiqueta __"</h2/>"__, y los títulos referidos a 1.1, 1.2, 1.3, 1.4, y 1.5  aparecen en una etiqueta __"</h3/>"__. Además pueden encontrarse también listados al principio de la página html

# %% [raw]
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Pintura"><span class="tocnumber">1</span> <span class="toctext">Pintura</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Viaje_a_Italia_1600-1608"><span class="tocnumber">1.1</span> <span class="toctext">Viaje a Italia 1600-1608</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Retorno_a_Amberes_en_1608"><span class="tocnumber">1.2</span> <span class="toctext">Retorno a Amberes en 1608</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Creación_de_su_taller_en_1615"><span class="tocnumber">1.3</span> <span class="toctext">Creación de su taller en 1615</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Départ_de_Van_Dyck_en_Angleterre_en_1620"><span class="tocnumber">1.4</span> <span class="toctext">Départ de Van Dyck en Angleterre en 1620</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Pinturas_de_los_últimos_años"><span class="tocnumber">1.5</span> <span class="toctext">Pinturas de los últimos años</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-7"><a href="#Miscelánea"><span class="tocnumber">2</span> <span class="toctext">Miscelánea</span></a></li>
# <li class="toclevel-1 tocsection-8"><a href="#Dibujo"><span class="tocnumber">3</span> <span class="toctext">Dibujo</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#Estampas"><span class="tocnumber">4</span> <span class="toctext">Estampas</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#Notas"><span class="tocnumber">5</span> <span class="toctext">Notas</span></a></li>
# <li class="toclevel-1 tocsection-11"><a href="#Referencias"><span class="tocnumber">6</span> <span class="toctext">Referencias</span></a></li>
# <li class="toclevel-1 tocsection-12"><a href="#Enlaces_externos"><span class="tocnumber">7</span> <span class="toctext">Enlaces externos</span></a></li>
# </ul>

# %% [markdown]
# Para recuperar el contenido de la página html de wikipedia, se puede hacer de la siguiente manera:

# %%
import requests
url="https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens"
r = requests.get(url)
html = r.text
print(html)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="es" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Anexo:Cuadros de Pedro Pablo Rubens - Wikipedia, la enciclopedia libre</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"e2e6c470-5c33-4c13-9dd7-d72e40d919fe","wgCSPNonce":!1,"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":104,"wgPageName":"Anexo:Cuadros_de_Pedro_Pablo_Rubens","wgTitle":"Cuadros de Pedro Pablo Rubens","wgCurRevisionId":139254471,"wgRevisionId":139254471,"wgArticleId":5344695,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Páginas con argumentos formatnum no numéricos","Wikipedia:Páginas con referencias con parámetros desconocidos","Wikipedia:Páginas con referencias con parámetros sugeridos","Wikipedia:Traducciones para mejorar",
# "Wikipedia:Páginas con enlaces rotos a archivos","Cuadros de Pedro Pablo Rubens","Anexos:Pintura"],"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgRelevantPageName":"Anexo:Cuadros_de_Pedro_Pablo_Rubens","wgRelevantArticleId":5344695,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":!0,"wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!1,"wgGELinkRecommendationsFrontendEnabled":!0,"wgCentralAuthMobileDomain":
# !1,"wgWikibaseItemId":"Q24932403"};RLSTATE={"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","skins.vector.legacy.js","ext.gadget.a-commons-directo","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns",
# "ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.centralauth.centralautologin"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});mw.user.options.set({"variant":"es"});
# });});</script>
# <link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?lang=es&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=ext.gadget.imagenesinfobox&amp;only=styles&amp;skin=vector"/>
# <link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <noscript><link rel="stylesheet" href="/w/load.php?lang=es&amp;modules=noscript&amp;only=styles&amp;skin=vector"/></noscript>
# <meta name="generator" content="MediaWiki 1.38.0-wmf.5"/>
# <meta name="referrer" content="origin"/>
# <meta name="referrer" content="origin-when-crossorigin"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta name="format-detection" content="telephone=no"/>
# <meta property="og:title" content="Anexo:Cuadros de Pedro Pablo Rubens - Wikipedia, la enciclopedia libre"/>
# <meta property="og:type" content="website"/>
# <link rel="preconnect" href="//upload.wikimedia.org"/>
# <link rel="alternate" media="only screen and (max-width: 720px)" href="//es.m.wikipedia.org/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens"/>
# <link rel="alternate" type="application/x-wiki" title="Editar" href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (es)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//es.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="https://creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-104 ns-subject mw-editable page-Anexo_Cuadros_de_Pedro_Pablo_Rubens rootpage-Anexo_Cuadros_de_Pedro_Pablo_Rubens skin-vector action-view skin-vector-legacy"><div id="mw-page-base" class="noprint"></div>
# <div id="mw-head-base" class="noprint"></div>
# <div id="content" class="mw-body" role="main">
# 	<a id="top"></a>
# 	<div id="siteNotice"><!-- CentralNotice --></div>
# 	<div class="mw-indicators">
# 	</div>
# 	<h1 id="firstHeading" class="firstHeading" >Anexo:Cuadros de Pedro Pablo Rubens</h1>
# 	<div id="bodyContent" class="vector-body">
# 		<div id="siteSub" class="noprint">De Wikipedia, la enciclopedia libre</div>
# 		<div id="contentSub"></div>
# 		<div id="contentSub2"></div>
#
# 		<div id="jump-to-nav"></div>
# 		<a class="mw-jump-link" href="#mw-head">Ir a la navegación</a>
# 		<a class="mw-jump-link" href="#searchInput">Ir a la búsqueda</a>
# 		<div id="mw-content-text" class="mw-body-content mw-content-ltr" lang="es" dir="ltr"><div class="mw-parser-output"><table style="" class="noprint plainlinks ambox ambox-style">
# <tbody><tr>
# <td class="ambox-image" width="40">
# <img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Translation_arrow.svg/45px-Translation_arrow.svg.png" decoding="async" width="45" height="15" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Translation_arrow.svg/68px-Translation_arrow.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2a/Translation_arrow.svg/90px-Translation_arrow.svg.png 2x" data-file-width="60" data-file-height="20" /></td>
# <td class="ambox-text"><div class="ambox-text-div"><strong>El texto que sigue es una traducción defectuosa.</strong> <span class="hide-when-compact">Si quieres colaborar con Wikipedia, busca el artículo original y <a class="external text" href="https://es.wikipedia.org/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=edit">mejora esta traducción</a>.</span></div><div class="hide-when-compact"><small>Copia y pega el siguiente código en la página de discusión del <a class="external text" href="https://es.wikipedia.org/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=history">autor de este artículo</a>: <code>{{subst:Aviso mal traducido|Anexo:Cuadros de Pedro Pablo Rubens}} ~~~~</code></small></div></td>
# </tr>
# </tbody></table>
# <p><b><a href="/wiki/Pedro_Pablo_Rubens" title="Pedro Pablo Rubens">Pedro Pablo Rubens</a></b> (<a href="/wiki/Siegen" title="Siegen">Siegen</a>, <a href="/wiki/Westfalia" title="Westfalia">Westfalia</a>, <a href="/wiki/28_de_junio" title="28 de junio">28 de junio</a> de <a href="/wiki/1577" title="1577">1577</a>-<a href="/wiki/Amberes" title="Amberes">Amberes</a>, <a href="/wiki/30_de_mayo" title="30 de mayo">30 de mayo</a> de <a href="/wiki/1640" title="1640">1640</a>), fue un <a href="/wiki/Pintor" title="Pintor">pintor</a> <a href="/wiki/Barroco" title="Barroco">barroco</a>, el más popular de la escuela flamenca. Su estilo exuberante enfatizaba el movimiento, el color y la sensualidad. Trató toda clase de temas pictóricos, de <a href="/wiki/Religi%C3%B3n" title="Religión">religión</a>, <a href="/wiki/Historia" title="Historia">historia</a>, <a href="/wiki/Mitolog%C3%ADa" title="Mitología">mitología</a> clásica, escenas de <a href="/wiki/Caza" title="Caza">caza</a>, <a href="/wiki/Retrato" title="Retrato">retratos</a> así como ilustraciones para libros y diseños para <a href="/wiki/Tapicer%C3%ADa" class="mw-redirect" title="Tapicería">tapicerías</a>. Fue muy prolífico en la producción de obras; se calcula que llegó a pintar unos 3000 cuadros gracias, en parte, a los miembros de su taller que, al parecer, trabajaban en cadena. Fueron discípulos suyos <a href="/wiki/Jacob_Jordaens" title="Jacob Jordaens">Jacob Jordaens</a> y <a href="/wiki/Anton_van_Dyck" title="Anton van Dyck">Anton van Dyck</a>. Dominaba varias lenguas y fue un gran <a href="/wiki/Humanista" class="mw-redirect" title="Humanista">humanista</a> y un buen diplomático.
# </p><p>Las pinturas de Rubens se pueden dividir entre aquellas que pintaba él mismo, las que pintaba en parte, principalmente las manos y rostros, y aquellas que únicamente supervisaba. Son reconocidas como propias las siguientes:
# </p><p><b>Lista de obras de Rubens</b>:
# </p>
# <div id="toc" class="toc" role="navigation" aria-labelledby="mw-toc-heading"><input type="checkbox" role="button" id="toctogglecheckbox" class="toctogglecheckbox" style="display:none" /><div class="toctitle" lang="es" dir="ltr"><h2 id="mw-toc-heading">Índice</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Pintura"><span class="tocnumber">1</span> <span class="toctext">Pintura</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Viaje_a_Italia_1600-1608"><span class="tocnumber">1.1</span> <span class="toctext">Viaje a Italia 1600-1608</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Retorno_a_Amberes_en_1608"><span class="tocnumber">1.2</span> <span class="toctext">Retorno a Amberes en 1608</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Creación_de_su_taller_en_1615"><span class="tocnumber">1.3</span> <span class="toctext">Creación de su taller en 1615</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Départ_de_Van_Dyck_en_Angleterre_en_1620"><span class="tocnumber">1.4</span> <span class="toctext">Départ de Van Dyck en Angleterre en 1620</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Pinturas_de_los_últimos_años"><span class="tocnumber">1.5</span> <span class="toctext">Pinturas de los últimos años</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-7"><a href="#Miscelánea"><span class="tocnumber">2</span> <span class="toctext">Miscelánea</span></a></li>
# <li class="toclevel-1 tocsection-8"><a href="#Dibujo"><span class="tocnumber">3</span> <span class="toctext">Dibujo</span></a></li>
# <li class="toclevel-1 tocsection-9"><a href="#Estampas"><span class="tocnumber">4</span> <span class="toctext">Estampas</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#Notas"><span class="tocnumber">5</span> <span class="toctext">Notas</span></a></li>
# <li class="toclevel-1 tocsection-11"><a href="#Referencias"><span class="tocnumber">6</span> <span class="toctext">Referencias</span></a></li>
# <li class="toclevel-1 tocsection-12"><a href="#Enlaces_externos"><span class="tocnumber">7</span> <span class="toctext">Enlaces externos</span></a></li>
# </ul>
# </div>
#
# <h2><span class="mw-headline" id="Pintura">Pintura</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=edit&amp;section=1" title="Editar sección: Pintura">editar</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="wikitable sortable" style="width:100%">
# <tbody><tr>
# <th>Imagen
# </th>
# <th>Título
# </th>
# <th>Dimensiones
# </th>
# <th width="70px">Fecha de creación
# </th>
# <th>Material
# </th>
# <th>Referencia
# </th>
# <th>Colección/localización
# </th></tr>
# <tr>
# <td><a href="/wiki/Archivo:Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg" class="image"><img alt="Peter Paul Rubens - Portrait of a Young Scholar - WGA20349.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/150px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg" decoding="async" width="150" height="237" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg/225px-Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/7/74/Peter_Paul_Rubens_-_Portrait_of_a_Young_Scholar_-_WGA20349.jp
jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5f/Rubens_Painting_Adam_Eve.jpg/300px-Rubens_Painting_Adam_Eve.jpg 2x" data-file-width="1514" data-file-height="1992" /></a>
# </td>
# <td><i>Adan y Eva</i>,  a partir de Rafael
# </td>
# <td><span style="white-space:nowrap">182x141&#160;cm</span>
# </td>
# <td><a href="/wiki/1599" title="1599">1599</a>
# </td>
# <td>Óleo sobre madera
# </td>
# <td><a rel="nofollow" class="external text" href="http://www.rubenshuis.be/fr/page/adam-et-eve-par-rubens">Musée</a>
# </td>
# <td><a href="/wiki/Rubenshuis" title="Rubenshuis">Rubenshuis</a>, Anvers
# </td></tr></tbody></table>
# <h3><span class="mw-headline" id="Viaje_a_Italia_1600-1608">Viaje a Italia 1600-1608</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=edit&amp;section=2" title="Editar sección: Viaje a Italia 1600-1608">editar</a><span class="mw-editsection-bracket">]</span></span></h3>
# <table class="wikitable sortable" style="width:100%">
# <tbody><tr>
# <th>Imagen
# </th>
# <th>Título
# </th>
# <th>Dimensiones
# </th>
# <th width="70px">Fecha de creación
# </th>
# <th>Material
# </th>
# <th>Referencia
# </th>
# <th>Colección/localización
# </th></tr>
# <tr>
# <td>
# </td>
# <td><i><a href="https://www.wikidata.org/wiki/Q21615081" class="extiw" title="d:Q21615081">Doopsel van Christus</a></i>
# </td>
# <td><i><a href="https://www.wikidata.org/wiki/Q3305213" class="extiw" title="d:Q3305213">peinture</a></i>
# </td>
# <td>1600s
# </td>
# <td>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Museo_Real_de_Bellas_Artes_de_Amberes" title="Museo Real de Bellas Artes de Amberes">Museo Real de Bellas Artes de Amberes</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Archivo:Painting_of_Susanna_and_the_Elders_by_Rubens.jpg" class="image"><img alt="Painting of Susanna and the Elders by Rubens.jpg" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/32/Painting_of_Susanna_and_the_Elders_by_Rubens.jpg/150px-Painting_of_Susanna_and_the_Elders_by_Rubens.jpg" decoding="async" width="150" height="225" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/32/Painting_of_Susanna_and_the_Elders_by_Rubens.jpg/225px-Painting_of_Susanna_and_the_Elders_by_Rubens.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/32/Painting_of_Susanna_and_the_Elders_by_Rubens.jpg/300px-Painting_of_Susanna_and_the_Elders_by_Rubens.jpg 2x" data-file-width="3814" data-file-height="5732" /></a>
# </td>
# <td><i>Susana y los viejos</i>
# </td>
# <td><span style="white-space:nowrap">94x67&#160;cm</span>
# </td>
# <td><a href="/wiki/1601" title="1601">1601</a>-<a href="/wiki/1602" title="1602">1602</a>
# </td>
# <td>Óleo sobre lienzo
# </td>
# <td><a rel="nofollow" class="external text" href="https://rkd.nl/en/explore/images/record?filters%5Bkunstenaar%5D%5B%5D=Rubens%2C+Peter+Paul&amp;filters%5Bobjectcategorie%5D%5B%5D=painting&amp;filters%5Bplaats_collectie_verblijfplaats%5D%5B%5D=Rome&amp;query=Rubens&amp;start=8">Base RKD</a>
# </td>
# <td><a href="/w/index.php?title=Galerie_Borgh%C3%A8se&amp;action=edit&amp;redlink=1" class="new" title="Galerie Borghèse (aún no redactado)">Galerie Borghèse</a><br /><a href="/w/index.php?title=Collection_Borgh%C3%A8se&amp;action=edit&amp;redlink=1" class="new" title="Collection Borghèse (aún no redactado)">collection Borghèse</a>
# </td></tr>
# <tr>
# <td>
# </td>
# <td><i>Couronnement d'épines ou le Christ moqué</i>
# </td>
# <td><span style="white-space:nowrap">224&#160;180<sup>cm</sup></span>
# </td>
# <td><a href="/wiki/1601" title="1601">1601</a>-<a href="/wiki/1602" title="1602">1602</a>
# </td>
# <td>Óleo sobre panel
# </td>
# <td><a rel="nofollow" class="external text" href="https://rkd.nl/en/explore/images/record?filters%5Bkunstenaar%5D=Rubens%2C+Peter+Paul&amp;filters%5Bkunstenaar_kwalificatie%5D%5B%5D=Rubens%2C+Peter+Paul&amp;filters%5Bobjectcategorie%5D%5B%5D=painting&amp;filters%5Bplaats_collectie_verblijfplaats%5D%5B%5D=Grasse+%28France%29&amp;query=&amp;start=0">Base RKD</a>
# </td>
# <td>Chapelle de l'hôpital, <a href="/wiki/Grasse" title="Grasse">Grasse</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Archivo:Peter_Paul_Rubens_-_Self-Portrait_in_a_Circle_of_Friends_from_Mantua_-_WGA20355.jp
# <td><a href="/wiki/1606" title="1606">1606</a> - <a href="/wiki/1608" title="1608">1608</a>
# </td>
# <td>Óleo sobre madera
# </td>
# <td><a rel="nofollow" class="external text" href="https://www.museodelprado.es/en/the-collection/art-work/the-judgement-of-paris/918bc2de-00a9-480d-87ba-96ac25f22bf4">Musée</a>
# </td>
# <td><a href="/wiki/Museo_del_Prado" title="Museo del Prado">Museo del Prado</a>, Madrid
# </td></tr>
# <tr>
# ...
#
# 	</div>
# </nav>
#
# 		<div id="left-navigation">
# 			<nav id="p-namespaces" class="mw-portlet mw-portlet-namespaces vector-menu vector-menu-tabs" aria-labelledby="p-namespaces-label" role="navigation"
# 	 >
# 	<h3 id="p-namespaces-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Espacios de nombres</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li id="ca-nstab-anexo" class="selected mw-list-item"><a href="/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens"><span>Anexo</span></a></li><li id="ca-talk" class="mw-list-item"><a href="/wiki/Anexo_discusi%C3%B3n:Cuadros_de_Pedro_Pablo_Rubens" rel="discussion" title="Discusión acerca de la página [t]" accesskey="t"><span>Discusión</span></a></li></ul>
#
# 	</div>
# </nav>
#
# 			<nav id="p-variants" class="mw-portlet mw-portlet-variants emptyPortlet vector-menu-dropdown-noicon vector-menu vector-menu-dropdown" aria-labelledby="p-variants-label" role="navigation"
# 	 >
# 	<input type="checkbox"
# 		id="p-variants-checkbox"
# 		role="button"
# 		aria-haspopup="true"
# 		data-event-name="ui.dropdown-p-variants"
# 		class="vector-menu-checkbox" aria-labelledby="p-variants-label" />
# 	<h3 id="p-variants-label" aria-label="Change language variant" class="vector-menu-heading">
#
# 		<span>Variantes</span>
# 			<span class="vector-menu-checkbox-expanded">expanded</span>
# 			<span class="vector-menu-checkbox-collapsed">collapsed</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"></ul>
#
# 	</div>
# </nav>
#
# 		</div>
# 		<div id="right-navigation">
# 			<nav id="p-views" class="mw-portlet mw-portlet-views vector-menu vector-menu-tabs" aria-labelledby="p-views-label" role="navigation"
# 	 >
# 	<h3 id="p-views-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Vistas</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li id="ca-view" class="selected mw-list-item"><a href="/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens"><span>Leer</span></a></li><li id="ca-edit" class="mw-list-item"><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=edit" title="Editar esta página [e]" accesskey="e"><span>Editar</span></a></li><li id="ca-history" class="mw-list-item"><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=history" title="Versiones anteriores de esta página [h]" accesskey="h"><span>Ver historial</span></a></li></ul>
#
# 	</div>
# </nav>
#
# 			<nav id="p-cactions" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu-dropdown-noicon vector-menu vector-menu-dropdown" aria-labelledby="p-cactions-label" role="navigation"  title="Más opciones"
# 	 >
# 	<input type="checkbox"
# 		id="p-cactions-checkbox"
# 		role="button"
# 		aria-haspopup="true"
# 		data-event-name="ui.dropdown-p-cactions"
# 		class="vector-menu-checkbox" aria-labelledby="p-cactions-label" />
# 	<h3 id="p-cactions-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Más</span>
# 			<span class="vector-menu-checkbox-expanded">expanded</span>
# 			<span class="vector-menu-checkbox-collapsed">collapsed</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"></ul>
#
# 	</div>
# </nav>
#
# 			<div id="p-search" role="search" class=" vector-search-box">
# 	<div>
# 			<h3 >
# 				<label for="searchInput">Buscar</label>
# 			</h3>
# 		<form action="/w/index.php" id="searchform"
# 			class="vector-search-box-form">
# 			<div id="simpleSearch"
# 				class="vector-search-box-inner"
# 				 data-search-loc="header-navigation">
# 				<input class="vector-search-box-input"
# 					 type="search" name="search" placeholder="Buscar en Wikipedia" aria-label="Buscar en Wikipedia" autocapitalize="sentences" title="Buscar en este wiki [f]" accesskey="f" id="searchInput"
# 				/>
# 				<input type="hidden" name="title" value="Especial:Buscar"/>
# 				<input id="mw-searchButton"
# 					 class="searchButton mw-fallbackSearchButton" type="submit" name="fulltext" title="Busca páginas con este texto." value="Buscar" />
# 				<input id="searchButton"
# 					 class="searchButton" type="submit" name="go" title="Ir a la página con este nombre exacto si existe" value="Ir" />
# 			</div>
# 		</form>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
# <div id="mw-panel">
# 	<div id="p-logo" role="banner">
# 		<a class="mw-wiki-logo" href="/wiki/Wikipedia:Portada"
# 			title="Visitar la página principal"></a>
# 	</div>
# 	<nav id="p-navigation" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" aria-labelledby="p-navigation-label" role="navigation"
# 	 >
# 	<h3 id="p-navigation-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Navegación</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li id="n-mainpage-description" class="mw-list-item"><a href="/wiki/Wikipedia:Portada" title="Visitar la página principal [z]" accesskey="z"><span>Portada</span></a></li><li id="n-portal" class="mw-list-item"><a href="/wiki/Portal:Comunidad" title="Acerca del proyecto, lo que puedes hacer, dónde encontrar información"><span>Portal de la comunidad</span></a></li><li id="n-currentevents" class="mw-list-item"><a href="/wiki/Portal:Actualidad" title="Encuentra información de contexto sobre acontecimientos actuales"><span>Actualidad</span></a></li><li id="n-recentchanges" class="mw-list-item"><a href="/wiki/Especial:CambiosRecientes" title="Lista de cambios recientes en el wiki [r]" accesskey="r"><span>Cambios recientes</span></a></li><li id="n-newpages" class="mw-list-item"><a href="/wiki/Especial:P%C3%A1ginasNuevas"><span>Páginas nuevas</span></a></li><li id="n-randompage" class="mw-list-item"><a href="/wiki/Especial:Aleatoria" title="Cargar una página al azar [x]" accesskey="x"><span>Página aleatoria</span></a></li><li id="n-help" class="mw-list-item"><a href="/wiki/Ayuda:Contenidos" title="El lugar para aprender"><span>Ayuda</span></a></li><li id="n-sitesupport" class="mw-list-item"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_es.wikipedia.org&amp;uselang=es" title="Apóyanos"><span>Donaciones</span></a></li><li id="n-bug_in_article" class="mw-list-item"><a href="/wiki/Wikipedia:Informes_de_error"><span>Notificar un error</span></a></li></ul>
#
# 	</div>
# </nav>
#
# 	<nav id="p-tb" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" aria-labelledby="p-tb-label" role="navigation"
# 	 >
# 	<h3 id="p-tb-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Herramientas</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li id="t-whatlinkshere" class="mw-list-item"><a href="/wiki/Especial:LoQueEnlazaAqu%C3%AD/Anexo:Cuadros_de_Pedro_Pablo_Rubens" title="Lista de todas las páginas del wiki que enlazan aquí [j]" accesskey="j"><span>Lo que enlaza aquí</span></a></li><li id="t-recentchangeslinked" class="mw-list-item"><a href="/wiki/Especial:CambiosEnEnlazadas/Anexo:Cuadros_de_Pedro_Pablo_Rubens" rel="nofollow" title="Cambios recientes en las páginas que enlazan con esta [k]" accesskey="k"><span>Cambios en enlazadas</span></a></li><li id="t-upload" class="mw-list-item"><a href="//commons.wikimedia.org/wiki/Special:UploadWizard?uselang=es" title="Subir archivos [u]" accesskey="u"><span>Subir archivo</span></a></li><li id="t-specialpages" class="mw-list-item"><a href="/wiki/Especial:P%C3%A1ginasEspeciales" title="Lista de todas las páginas especiales [q]" accesskey="q"><span>Páginas especiales</span></a></li><li id="t-permalink" class="mw-list-item"><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;oldid=139254471" title="Enlace permanente a esta versión de la página"><span>Enlace permanente</span></a></li><li id="t-info" class="mw-list-item"><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;action=info" title="Más información sobre esta página"><span>Información de la página</span></a></li><li id="t-cite" class="mw-list-item"><a href="/w/index.php?title=Especial:Citar&amp;page=Anexo%3ACuadros_de_Pedro_Pablo_Rubens&amp;id=139254471&amp;wpFormIdentifier=titleform" title="Información sobre cómo citar esta página"><span>Citar esta página</span></a></li><li id="t-wikibase" class="mw-list-item"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q24932403" title="Enlace al elemento conectado del repositorio de datos [g]" accesskey="g"><span>Elemento de Wikidata</span></a></li></ul>
#
# 	</div>
# </nav>
# <nav id="p-coll-print_export" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" aria-labelledby="p-coll-print_export-label" role="navigation"
# 	 >
# 	<h3 id="p-coll-print_export-label" aria-label="" class="vector-menu-heading">
#
# 		<span>Imprimir/exportar</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li id="coll-create_a_book" class="mw-list-item"><a href="/w/index.php?title=Especial:Libro&amp;bookcmd=book_creator&amp;referer=Anexo%3ACuadros+de+Pedro+Pablo+Rubens"><span>Crear un libro</span></a></li><li id="coll-download-as-rl" class="mw-list-item"><a href="/w/index.php?title=Especial:DownloadAsPdf&amp;page=Anexo%3ACuadros_de_Pedro_Pablo_Rubens&amp;action=show-download-screen"><span>Descargar como PDF</span></a></li><li id="t-print" class="mw-list-item"><a href="/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;printable=yes" title="Versión imprimible de esta página [p]" accesskey="p"><span>Versión para imprimir</span></a></li></ul>
#
# 	</div>
# </nav>
#
# 	<nav id="p-lang" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" aria-labelledby="p-lang-label" role="navigation"
# 	 >
# 	<h3 id="p-lang-label" aria-label="" class="vector-menu-heading">
#
# 		<span>En otros idiomas</span>
# 	</h3>
# 	<div class="vector-menu-content">
#
# 		<ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-el mw-list-item"><a href="https://el.wikipedia.org/wiki/%CE%9A%CE%B1%CF%84%CE%AC%CE%BB%CE%BF%CE%B3%CE%BF%CF%82_%CE%AD%CF%81%CE%B3%CF%89%CE%BD_%CF%84%CE%BF%CF%85_%CE%A0%CE%AD%CF%84%CE%B5%CF%81_%CE%A0%CE%AC%CE%BF%CF%85%CE%BB_%CE%A1%CE%BF%CF%8D%CE%BC%CF%80%CE%B5%CE%BD%CF%82" title="Κατάλογος έργων του Πέτερ Πάουλ Ρούμπενς (griego)" lang="el" hreflang="el" class="interlanguage-link-target"><span>Ελληνικά</span></a></li><li class="interlanguage-link interwiki-fr mw-list-item"><a href="https://fr.wikipedia.org/wiki/Liste_des_%C5%93uvres_de_Rubens" title="Liste des œuvres de Rubens (francés)" lang="fr" hreflang="fr" class="interlanguage-link-target"><span>Français</span></a></li><li class="interlanguage-link interwiki-nl mw-list-item"><a href="https://nl.wikipedia.org/wiki/Lijst_van_werken_van_Peter_Paul_Rubens" title="Lijst van werken van Peter Paul Rubens (neerlandés)" lang="nl" hreflang="nl" class="interlanguage-link-target"><span>Nederlands</span></a></li></ul>
# 		<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q24932403#sitelinks-wikipedia" title="Editar enlaces interlingüísticos" class="wbc-editpage">Editar enlaces</a></span></div>
# 	</div>
# </nav>
#
# </div>
#
# </div>
# <footer id="footer" class="mw-footer" role="contentinfo" >
# 	<ul id="footer-info">
# 	<li id="footer-info-lastmod"> Esta página se editó por última vez el 24 oct 2021 a las 16:03.</li>
# 	<li id="footer-info-copyright">El texto está disponible bajo la <a rel="license" href="//es.wikipedia.org/wiki/Wikipedia:Texto_de_la_Licencia_Creative_Commons_Atribuci%C3%B3n-CompartirIgual_3.0_Unported">Licencia Creative Commons Atribución Compartir Igual 3.0</a><a rel="license" href="http://creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestros <a href="//wikimediafoundation.org/wiki/Terms_of_Use">términos de uso</a> y nuestra <a href="//wikimediafoundation.org/wiki/Privacy_policy">política de privacidad</a>. <br/>Wikipedia&reg; es una marca registrada de la <a href="//www.wikimediafoundation.org/">Fundación Wikimedia, Inc.</a>, una organización sin ánimo de lucro.</li>
# </ul>
#
# 	<ul id="footer-places">
# 	<li id="footer-places-privacy"><a href="https://meta.wikimedia.org/wiki/Privacy_policy/es" class="extiw" title="m:Privacy policy/es">Política de privacidad</a></li>
# 	<li id="footer-places-about"><a href="/wiki/Wikipedia:Acerca_de" title="Wikipedia:Acerca de">Acerca de Wikipedia</a></li>
# 	<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:Limitaci%C3%B3n_general_de_responsabilidad" title="Wikipedia:Limitación general de responsabilidad">Limitación de responsabilidad</a></li>
# 	<li id="footer-places-mobileview"><a href="//es.m.wikipedia.org/w/index.php?title=Anexo:Cuadros_de_Pedro_Pablo_Rubens&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Versión para móviles</a></li>
# 	<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Desarrolladores</a></li>
# 	<li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/es.wikipedia.org">Estadísticas</a></li>
# 	<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement/es">Declaración de cookies</a></li>
# </ul>
#
# 	<ul id="footer-icons" class="noprint">
# 	<li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation" loading="lazy" /></a></li>
# 	<li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img src="/static/images/footer/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88" height="31" loading="lazy"/></a></li>
# </ul>
#
# </footer>
#
#
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"2.347","walltime":"2.971","ppvisitednodes":{"value":15488,"limit":1000000},"postexpandincludesize":{"value":55499,"limit":2097152},"templateargumentsize":{"value":5982,"limit":2097152},"expansiondepth":{"value":13,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":15206,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  530.684      1 -total"," 47.90%  254.174    356 Plantilla:Unidad"," 17.86%   94.792      1 Plantilla:Listaref"," 10.55%   55.992      1 Plantilla:M","  9.72%   51.582      4 Plantilla:Ouvrage","  9.67%   51.342      1 Plantilla:Commonscat","  6.79%   36.025      1 Plantilla:Reemplazar","  3.25%   17.247      4 Plantilla:Article","  2.36%   12.539      1 Plantilla:Propiedad","  2.25%   11.950    157 Plantilla:Exp"]},"scribunto":{"limitreport-timeusage":{"value":"0.046","limit":"10.000"},"limitreport-memusage":{"value":2913929,"limit":52428800}},"cachereport":{"origin":"mw1326","timestamp":"20211025211122","ttl":1814400,"transientcontent":false}}});mw.config.set({"wgBackendResponseTime":3158,"wgHostname":"mw1326"});});</script>
# </body></html>

# %% [markdown]
# Se pide hacer un buscador que permita recuperar información de la página. Para ello se le mostrará al usuario tres opciones entre las que tiene que elegir: Buscar por etapa pictórica, Buscar por material o Buscar por museo.
#
# __Buscar por etapa pictórica[2,5 puntos]__
#
# Si elige esta opción se le mostrará un listado de todas las etapas que aparecen en wikipedia antes mencionadas. Para facilitar la selección se asignará un número a cada etapa, de manera que el usuario elija por número.Las etapas pueden recuperarse de acuerdo a la caracterización antes indicada (bien usando las etiquetas h2 y h3 o bien por el listado que aparece al comienzo de la página). Una vez elegido una etapa, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título,Dimensiones, Fecha de creación, Referencia, Colección/localización. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre etapa pictórica.
#
# __Buscar por material[2,5 puntos]__
#
# Si elige esta opción se le mostrará un listado de todos los tipos de materiales usados por Rubens para pintar sus cuadros. Para facilitar la selección se asignará un número a cada tipo de material, de manera que el usuario elija por número.Los materiales se pueden recuperar de la  columna Material de cada tabla de la página de wikipedia. Una vez elegida una técnica, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas:  Título,Dimensiones, Fecha de creación, Referencia, Colección/localización. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre ese material.
#
# __Buscar por museo[5 puntos]__
#
# Si elige esta opción se le mostrará un listado de todos los museos en los que existe una pintura de Rubens. Para facilitar la selección se asignará un número a cada museo, de manera que el usuario elija por número. Los museos se pueden recuperar de la  columna Colección/Localización de cada tabla de la página de wikipedia. Una vez elegido el museo, el programa mostrará una lista de todas las pinturas que cumplen ese requisito. De cada pintura se mostrará la información que aparece en las columnas: Título,Dimensiones, Fecha de creación, Referencia, Colección/localización. Así mismo, se creará una carpeta en el sistema de archivos, y se guardarán todas las imagenes de las pinturas que cumplen la condición de búsqueda sobre museo.
#
# Después de hacer uso de cualquier búsqueda, se le preguntará al usuario si quiere volver a buscar. En tal caso, se le mostrará otra vez el menú, y en caso contrario, se saldrá de la ejecución del mismo.
#
# __Nota: Para procesar la página html es obligatorio utilizar la libreria BeautifulSoup. No se pueden usar otras librerías no vistas en clase__

# %% [markdown]
# # Normas de entrega
#
# * Fecha tope de entrega: 28/10/2021
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre WebScraping_GrupoX donde X será el número de grupo correspondiente.

# %% [markdown]
# __MENÚ Y FUNCIÓN PRINCIPAL__

# %%
import urllib
import re
from bs4 import BeautifulSoup
 
html=urllib.request.urlopen("https://es.wikipedia.org/wiki/Anexo:Cuadros_de_Pedro_Pablo_Rubens").read()
soup=BeautifulSoup(html,'html.parser')

# %%
tablas = soup("table")
num_pinturas = 0
lista_pinturas = list()

CLEANR = re.compile('<.*?>')
def _cleanhtml(raw_html):
    cleantext = re.sub(CLEANR, '', raw_html)
    return cleantext

for i in range(1, 7):

    filas_tabla = tablas[i]("tr")

    for j in range(1, len(filas_tabla)):
        try:
            fila_contents = filas_tabla[j].contents
            lista_pinturas.append(dict())
            try:
                lista_pinturas[num_pinturas]["image"] = fila_contents[1].contents[0].contents[0].get("src", None) #hecho
            except:
                lista_pinturas[num_pinturas]["image"] = None
            try:
                lista_pinturas[num_pinturas]["title"] = _cleanhtml(str(fila_contents[3]))
            except:
                lista_pinturas[num_pinturas]["title"] = None               
            try: 
                lista_pinturas[num_pinturas]["dimensions"] = _cleanhtml(str(fila_contents[5])) #hecho
            except:
                lista_pinturas[num_pinturas]["dimensions"] = None
            try:
                lista_pinturas[num_pinturas]["date"] = _cleanhtml(str(fila_contents[7])) #hecho
            except:
                lista_pinturas[num_pinturas]["date"] = None
            try:
                lista_pinturas[num_pinturas]["material"] = _cleanhtml(str(fila_contents[9])) #hecho
                if lista_pinturas[num_pinturas]["material"] == "\n":
                    lista_pinturas[num_pinturas]["material"] = None
            except:
                lista_pinturas[num_pinturas]["material"] = None
            try:
                lista_pinturas[num_pinturas]["references"] = fila_contents[11].contents[0].get("href", None) #hecho
            except:
                lista_pinturas[num_pinturas]["references"] = None
            try:
                try:
                    lista_pinturas[num_pinturas]["localization"] = _cleanhtml(str(fila_contents[13])) #hecho
                except:
                    lista_pinturas[num_pinturas]["localization"] = None
            except:
                lista_pinturas[num_pinturas]["localization"] = None
            num_pinturas += 1
        except:
            num_pinturas += 1

# %%
lista_museos = list()

for pintura in lista_pinturas:
    localization = pintura.setdefault("localization", None)
    if  pintura["localization"] != None:
        if pintura["localization"] not in lista_museos:
            lista_museos.append(pintura["localization"])

# %%
import os
import urllib.request

def print_museos():
    cont = 1
    for i in lista_museos:
        print(str(cont) + ".- " + i)
        cont += 1

def pinturas_por_museo(museo):
    lista_pinturas_por_museo = list()
    for i in lista_pinturas:
        if i['localization'] == museo:
            lista_pinturas_por_museo.append(i)
    

    return lista_pinturas_por_museo
            
def print_pinturas(pinturas):
    #Título,Dimensiones, Fecha de creación, Referencia, Colección/localización.
    for i in pinturas:
        print("-----------------------------------------------------------------------------------")
        print("Título: " + i['title'])
        print("Dimensiones: " + i['dimensions'])
        print("Fecha: " + i['date'])
        print("Localización/Colección: " + i['localization'])
        print("Referencias: " + i['references'])
        print("-----------------------------------------------------------------------------------")


def guardar_pinturas(lista_pinturas_por_museo):
    carpeta_inicial = os.getcwd()
    carpeta = str(str(lista_pinturas_por_museo[0]['localization']).strip("\n"))
    if not os.path.exists(carpeta):
        os.mkdir(carpeta)
        os.chdir(carpeta)
        for i in lista_pinturas_por_museo:
            if i['image'] != None:
                img = urllib.request.urlopen("https:" + i["image"]).read()
                manf=open(i['title'].strip("\n(?)") + ".jpg","wb")
                manf.write(img)
                manf.close()
        os.chdir(carpeta_inicial)

def func3():
    print_museos()
    opt = int(input("Seleccione un museo (0 para salir): "))
    if opt > 0:
        museo = lista_museos[opt - 1]
        lista_pinturas_por_museo = pinturas_por_museo(museo)
        print_pinturas(lista_pinturas_por_museo)
        guardar_pinturas(lista_pinturas_por_museo)

# %%
func3()
# Out:
# 1.- Metropolitan Museum of Art
#
# 2.- National Gallery de Londres
#
# 3.- Musée des beaux-arts de Houston
#
# 4.- Rubenshuis, Anvers
#
# 5.- Museo Real de Bellas Artes de Amberes
#
# 6.- Galerie Borghèsecollection Borghèse
#
# 7.- Chapelle de l'hôpital, Grasse
#
# 8.- Wallraf-Richartz Museum, Cologne
#
# 9.- Museo Nacional de Escultura, Valladolid
#
# 10.- collection particulière
#
# 11.- Museo del Prado, Madrid
#
# 12.- Palazzo Ducale
#
# 13.- National Gallery of Art
#
# 14.- Église du Gesù (Gênes)
#
# 15.- Palazzo Spinola di Pellicceria, Gênes
#
# 16.- Académie des beaux-arts de Vienne
#
# 17.- National Gallery of Art, Washington D. C.
#
# 18.- The Bankes Collection, Kingston Lacy, Wimborne Minster
#
# 19.- département des peintures du musée du Louvre
#
# 20.- Musée de Grenoble
#
# 21.- Museo Thyssen-Bornemisza
#
# 22.- National Trust
# Kinston Lacy (Wimborne)
#
#
# 23.- Université de Californie, Los Ángeles
#
# 24.- Chiesa Nuova, Roma
#
# 25.-
#
# 26.- Real Academia de Bellas Artes de San Fernando, Madrid
#
# 27.- Pinacoteca civica, Palazzo dei PrioriFermo
#
# 28.- Museo del Hermitage, San Petersburgo
#
# 29.- Institut Courtauld, Londres
#
# 30.- Musée des beaux-arts de Boston
#
# 31.- Palazzo Corsini, Rome
#
# 32.- Musée d'art du comté de Los Angeles
#
# 33.- Pinacoteca Antigua de Múnich
#
# 34.- Institut d'art de Chicago
#
# 35.- Museo Thyssen-Bornemisza, Madrid
#
# 36.- Museo del Hermitage, San Petersburgo
#
#
#
# 37.- Rubenshuis
#
# 38.- Musée Boijmans Van Beuningen, Róterdam
#
# 39.- J. Paul Getty Museum
#
# 40.- Musée de l'Ermitage, Saint Petersbourg
#
# 41.- Courtauld Gallery, Londres
#
# 42.- Musée des beaux-arts de San Francisco
#
# 43.- Collection privéeVente 6 juillet 2010, Londres
#
# 44.- Palais Schwarzenberg, Vienne
#
# 45.- Galerie Palatine, Palacio Pitti, Florencia
#
# 46.- Catedral de Amberes
#
# 47.- Musée de l'Ermitage
#
# 48.- Musée des beaux-arts de l'Ontario
#
# 49.- J. Paul Getty Museum, Los Angeles
#
# 50.- Musée des Beaux-Arts de Marseille
#
# 51.- Catedral de Amberes&lt;
#
# 52.- Musées du Capitole
#
# 53.- Musée des Beaux-Arts de Valenciennes
#
# 54.- Museum Schloss Wilhelmshöhe, Kassel
#
# 55.- Liechtenstein Museum, Vienne
#
# 56.- Musée national de Varsovie
#
# 57.- Musée royal des beaux-arts d'Anvers
#
# 58.- Gemäldegalerie (Berlin)
#
# 59.- Nationalmuseum, Stockolm
#
# 60.- Museo de Historia del Arte de Viena
#
# 61.- Château Wilhelmshöhe, Kassel
#
# 62.- Museo de Israel, Jerusalén
#
# 63.- Wallace Collection, Londres
#
# 64.- Galerie Palatine, Florence
#
# 65.- Philadelphia Museum of Art
#
# 66.- Statens Museum for Kunst, Copenhague
#
# 67.- Galerie nationale d'Écosse, Edimbourg
#
# 68.- Musée des beaux-arts de Tours
#
# 69.- Musée du Louvre, Paris
#
# 70.- Museos Capitolinos
#
# 71.- Galería de Arte de Ontario
#
# 72.- Museo Nacional de Arte Occidental, Tokio
#
# 73.- Convento de las Agustinas e Iglesia de la Purísima, Salamanca
#
# 74.- Musée Fabre, Montpellier
#
# 75.- Palais des beaux-arts de Lille
#
# 76.- Collection Privée, Madrid(anciennement Bentinck-Thyssen[5]​)
#
# 77.- Mauritshuis, La Haya
#
# 78.- Musée des beaux-arts Pouchkine, Moscou
#
# 79.- Département des peintures du musée du Louvre
#
# 80.- Metropolitan Museum of Art, New York
#
# 81.- Église Saint-Géry de Cambrai
#
# 82.- Musée d'histoire de l'art de Vienne
#
# 83.- Smithsonian American Art Museum, Washington
#
# 84.- Mauritshuis, La Haye
#
# 85.- Musée des beaux-arts de Rennes
#
# 86.- Musée des beaux-arts de Caen
#
# 87.- Musée des Offices, Florence
#
# 88.- Museo Liechtenstein, Viena
#
# 89.- Gemäldegalerie, Berlin, perdu en 1945
#
# 90.- Musée des beaux-arts de Gand
#
# 91.- Gemäldegalerie Alte Meister, Dresde
#
# 92.- Musée des beaux-arts de Lyon
#
# 93.- Alte Pinakothek
#
# 94.- Collection du Prince du Liechtenstein, Vaduz
#
# 95.- Collection Thyssen-Bornemiszaprêt permanent au Musée national d'art de Catalogne
#
# 96.- Gemäldegalerie
#
# 97.- Musée des beaux-arts de Budapest
#
# 98.- Musée des beaux-arts de Quimper
#
# 99.- Cathédrale Saint-Bavon de Gand
#
# 100.- Seattle Art Museum
#
# 101.- Musée de l'Ermitage, St Petersbourg
#
# 102.- National Gallery of Victoria, Melbourne
#
# 103.- Galerie d'art de Nouvelle-Galles du Sud, Sydney
#
# 104.- Philadelphia Museum of ArtMobilier nationalmusée d'art d'Indianapolis
#
# 105.- Royal Collection, Royaume-Uni
#
# 106.- Galerie nationale d'Australie, Canberra
#
# 107.- Musée de la chasse et de la nature, Paris
#
# 108.- Musée royal des Beaux-Arts d'Anvers
#
# 109.- Musée Bonnat, Bayonne
#
# 110.- Kimbell Art Museum, Fort Worth
#
# 111.- Château de Schleissheim, Oberschleissheim
#
# 112.- Cathédrale Notre-Dame d'Anvers
#
# 113.- Galerie nationale de Prague
#
# 114.- Musée Herzog Anton Ulrich, Brunswick
#
# 115.- Colección Villar Mir, Madrid
#
# 116.- musée Boijmans Van Beuningen, Róterdam
#
# 117.- Dulwich Picture Gallery, Londres
#
# 118.- Musée Calouste Gulbenkian, Lisbonne
#
# 119.- Kunsthistorisches Museum, Viena
#
# 120.- Musée des Augustins de Toulouse
#
# 121.- Rijksmuseum Ámsterdam
#
# 122.- Pinacothèque de Brera, Milan
#
# 123.- Allen Memorial Art Museum, Oberlin, Ohio
#
# 124.- Minneapolis Institute of Art
#
# 125.- Maison des banquets, Palais de Whitehall, Londres
#
# 126.- National Gallery
#
# 127.- Musée des beaux-arts de Bordeaux
#
# 128.- Musées royaux des beaux-arts de Belgique, Bruxelles
#
# 129.- Musée de l'Ermitage, Saint-Pétersbourg
#
# 130.- Musées royaux des beaux-arts de BelgiqueBruxelles
#
# 131.- Musée d'arts de Nantes
#
# 132.- Musée du Louvre
#
# 133.- Église Saint Jacques, Anvers
#
# 134.- Musée Bonnat-Helleu
#
# 135.- Galeria Palatina, Palacio Pitti, Florencia
#
# 136.- musée de l'Ermitage
#
# 137.- Galerie Sabauda, Turin
#
# 138.- Collection Belfius, Paribas, Bruxelles
#
# 139.- Statens Museum for Kunst
#
# -----------------------------------------------------------------------------------
# Título: Retrato del Marqués Ambrogio Spinola
#
# Dimensiones: 117 85cm
#
# Fecha: ca. 1627
#
# Localización/Colección: Galerie nationale de Prague
#
# Referencias: https://rkd.nl/en/explore/images/record?filters%5Bkunstenaar%5D%5B%5D=Rubens%2C+Peter+Paul&filters%5Bobjectcategorie%5D%5B%5D=painting&filters%5Bplaats_collectie_verblijfplaats%5D%5B%5D=Praag&query=Rubens&start=6
# -----------------------------------------------------------------------------------

# %%
def menu():
    print("MENU")
    print("1.- Buscar por etapa pictórica")
    print("2.- Buscar por material")
    print("3.- Buscar por museo")
    print("4.- Salir")

    option = int(input())
    return option

def funcPrincipal():
    op = menu()
    while op < 1 or op > 4:
        print("Opción inválida, introduzca de nuevo la opción")
        op = menu()

    if op == 1:
        func1()
        option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()
        while option == 's':
          func1()
          option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()
    elif op == 2:
        func2()
        option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()
        while option == 's':
          func2()
          option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()
    elif op == 3:
        func3()
        option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()
        while option == 's':
            func3()
            option = input("¿Quiere realizar una nueva búsqueda? (s/n)").lower()

    if op != 4:
      funcPrincipal()

funcPrincipal()
