# %% [markdown]
# ### Práctica de Formatos de datos: XML

# %% [markdown]
# El objetivo de esta práctica es crear una aplicación que gestionará información sobre los alojamientos de la ciudad de Madrid incluyendo hoteles, hostales, pensiones y campings.
#
# Para ello se va a usar el catálogo "Alojamientos de la ciudad de Madrid" del portal de datos abiertos del Ayuntamiento de Madrid. La información incluye los datos básicos de cada punto, una descripción, su geoposición y dirección postal, así como un conjunto de fotografías relativas a cada punto. En los casos en los que aplica, se ofrecen horarios de apertura y costes de acceso si los tuviera. La información se encuentra en:
# https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=df42a73970504510VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default
#
# Y el conjunto de datos XML que hay que procesar está situado en:
# https://datos.madrid.es/egob/catalogo/300032-10037102-turismo-alojamientos.xml
#
# Junto al enunciado de la práctica se proporciona el fichero xml a tratar. El siguiente trozo de código permite recuperar el archivo xml en cuestion, y mostrar su contenido.

# %%
from xml.etree import ElementTree
from xml.dom import minidom
def prettify(elem):
    """Return a pretty-printed XML string for the Element."""
    rough_string=ElementTree.tostring(elem,"utf-8")
    reparsed=minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ")

f=open("alojamientos_v1_es.xml","rt",encoding="utf8")
arbol=ElementTree.parse(f)
raiz=arbol.getroot()
print (prettify(raiz))
# Out:
# <?xml version="1.0" ?>
# <serviceList>
#   <service fechaActualizacion="2021-09-27" id="97833">
#     <basicData>
#       <language>es</language>
#       <name>Oxygen Hostel</name>
#       <email>oxygenmadrid19@gmail.com</email>
#       <phone>+34 686 81 12 61</phone>
#       <fax/>
#       <title>Oxygen Hostel</title>
#       <body>&lt;p&gt;&lt;strong&gt;En una inmejorable situación, muy cerca de Atocha y del Paseo del Arte, se encuentra este hotel cápsula, el primero en ofrecer un estilo&amp;nbsp;de alojamiento&amp;nbsp;futurista y &lt;em&gt;low cost &lt;/em&gt;en Madrid.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Disponen de 22 cápsulas, 10 dobles y 12 sencillas, todas equipadas con baños individuales independientes, aire acondicionado y WiFi. Además, ofrecen la posibilidad de trabajar en ellas.&lt;/p&gt;&lt;p&gt;Cuentan con dos zonas comunes, salón y cocina, recepción 24 horas y organizan excursiones.No admiten mascotas.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/oxygen-hostel</web>
#     </basicData>
#     <geoData>
#       <address>Rafael Riego, 19</address>
#       <zipcode>28045</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.403528800000</latitude>
#       <longitude>-3.692084400000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/oxygen_hostel.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/oxygen_hostel_.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/ox.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/oxigen_hostle.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7029</item>
#           <item name="Categoria">Hostales</item>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-09-15" id="97799">
#     <basicData>
#       <language>es</language>
#       <name>Canopy by Hilton Madrid Castellana </name>
#       <email/>
#       <phone>+34 911 44 04 45</phone>
#       <fax/>
#       <title>Canopy by Hilton Madrid Castellana </title>
#       <body>&lt;p&gt;&lt;strong&gt;Canopy by Hilton Madrid Castellana está situado en la plaza Carlos Trías Bertrán, en pleno barrio de la Castellana, muy cerca del Estadio Santiago Bernabéu y del complejo AZCA.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este hotel &lt;em&gt;boutique&lt;/em&gt;, perteneciente a la marca &lt;em&gt;lifestyle &lt;/em&gt;de Hilton, inspirada en la cultura local, tiene un interiorismo basado en el rojo Madrid y filosofía cañí, que refleja la cultura popular madrileña desde el diseño más vanguardista. Sus 314 habitaciones y 12 salas de reuniones tienen un marcado carácter urbano y local que lo convierten en un establecimiento multifuncional y en un prescriptor de cercanía del nuevo&lt;em&gt; comfy&lt;/em&gt; contemporáneo.&lt;br /&gt;Situado en el &lt;em&gt;lobby,&lt;/em&gt; nombrado como Canopy Central, se encuentra un espacio gastronómico donde los visitantes pueden disfrutar de un café de autor o de platos preparados con ingredientes locales y saludables en su restaurante Escándalo. Su exclusiva terraza de la piscina, con vistas al &lt;em&gt;skyline&lt;/em&gt; de Madrid, se convertirá para sus huéspedes en un escenario tan romántico como típicamente madrileño. Para completar esta experiencia cien por cien local, el hotel da la bienvenida obsequiando con los icónicos caramelos de violeta a sus clientes, un recuerdo que ningún visitante de Madrid debería perderse.&lt;/p&gt;&lt;p&gt;Además, tanto locales como visitantes podrán visitar su espectacular terraza, Planta Z, donde&amp;nbsp; pueden degustar divertidos platos de estilo &lt;em&gt;street food &lt;/em&gt;amenizados por música en directo.&lt;br /&gt;&amp;nbsp;&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/canopy-hilton-madrid-castellana</web>
#     </basicData>
#     <geoData>
#       <address>Carlos Trías Bertrán, 4</address>
#       <zipcode>28020</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.451381600000</latitude>
#       <longitude>-3.693585400000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-103.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-112.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-189.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-027.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-170.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-148.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/canopy_hilton-m_yllera-157.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-07-07" id="97373">
#     <basicData>
#       <language>es</language>
#       <name>Atocha Hotel Madrid, Tapestry Collection by Hilton</name>
#       <email>tapestryatocha@hilton.com</email>
#       <phone>+34 610 44 01 15</phone>
#       <fax/>
#       <title>Atocha Hotel Madrid, Tapestry Collection by Hilton</title>
#       <body>&lt;p&gt;&lt;strong&gt;A unos pasos del Paseo del Arte y de la estación de Atocha, se encuentra este alojamiento&amp;nbsp;de la marca hotelera Tapestry by Hilton.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este hotel boutique, el primero de la marca Tapestry que se instala en España y fuera de América, cuenta con 46 habitaciones, divididas en ocho opciones, entre las que se encuentran, la Atocha Suite, situada en el ático y con diseño art decó, o la Five Feet to Fitness, que permite a los huéspedes realizar ejercicio físico y entrenar. Además, cuenta con wifi gratis, gimnasio y&amp;nbsp;salas de reuniones.&lt;/p&gt;&lt;p&gt;Ubicado en la planta baja del hotel, se encuentra&amp;nbsp;el nuevo proyecto del chef Joaquín Felipe, el restaurante Atocha 107. Dividido en un salón comedor y un acogedor y tranquilo patio, ofrece dos menús degustación: el karnívoro, compuesto por un guiso de alubias rojas de Tolosa, chuleta de vaca madurada y tarta de queso, maridado con vinos de Arganda y de Uclés, café y gin tonic, y otro que va cambiando semanalmente según la inspiración del chef. Además, cuenta con una carta con platos muy castizos.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/atocha-hotel-madrid-tapestry-collection-hilton</web>
#     </basicData>
#     <geoData>
#       <address>Atocha, 107</address>
#       <zipcode>28012</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.410605900000</latitude>
#       <longitude>-3.695301100000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop02d.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop02c.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop02a.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_122019.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop03b.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop03c.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mast_prop02b.jpeg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/sin_titulo.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-06-30" id="97242">
#     <basicData>
#       <language>es</language>
#       <name>Hard Rock Hotel Madrid</name>
#       <email>reservations@hrhmadrid.com</email>
#       <phone/>
#       <fax/>
#       <title>Hard Rock Hotel Madrid</title>
#       <body>&lt;p&gt;&lt;strong&gt;A unos pasos de la Estación de Atocha y el Paseo del Arte, tiene su ubicación el nuevo hotel de la cadena Hard Rock Internacional.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este cuatro estrellas, en el que la música tiene un especial protagonismo, cuenta con 161 habitaciones y suites, inspiradas en un estilo rockero inconfundible, con presencia de arte contemporáneo tanto en sus paredes como en su lujosa ropa de cama. Todas ellas tienen&amp;nbsp;desde canales de música gratuitos hasta barras de sonido y minibar con cafetera Lavazza. La joya de la corona es The Sound of Your Stay&amp;reg;, un programa musical con alquiler de guitarras Fender&amp;reg; y &lt;em&gt;playlists&lt;/em&gt; personalizadas.&amp;nbsp;Además, el hotel, siguiendo el hilo conductor de la música, ofrece los servicios&amp;nbsp;&lt;strong&gt;Rock Om&lt;/strong&gt;, clases de yoga a ritmo de una banda sonora seleccionada por un DJ, cuenta con &lt;strong&gt;Body Rock&amp;reg;&lt;/strong&gt;, un centro &lt;em&gt;fitness&lt;/em&gt; 24 horas, equipado con máquinas de última generación, música para entrenar duro y wifi gratuito y, por último, una piscina exterior inspirada en la música.&lt;/p&gt;&lt;p&gt;Por si esto si fuera poco, suma a sus intalaciones cinco espacios gastronómicos: &lt;strong&gt;Sessions Restaurant&lt;/strong&gt;, un restaurante de cocina de autor,&amp;nbsp;donde disfrutar de la cocina española y una decoración repleta de detalles musicales; &lt;strong&gt;RT60&lt;/strong&gt;, un &lt;em&gt;roof top&lt;/em&gt; con vistas 360 grados del centro de Madrid, comida sabrosa, bebidas fuertes y música de un DJ&amp;nbsp;en directo; &lt;strong&gt;GMT+1&lt;/strong&gt;, el &lt;em&gt;lobby&lt;/em&gt; bar, donde celebrar reuniones informales o tomar una copa; &lt;strong&gt;Green Room&lt;/strong&gt;, junto al restaurante Sessions, un reservado con una carta exclusiva para máximo 10 comensales y el &lt;strong&gt;Roxy Lounge&lt;/strong&gt;, un espacio junto al jardín, perfecto para celebraciones y ocasiones especiales.&lt;br /&gt;&amp;nbsp;&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/hard-rock-hotel-madrid</web>
#     </basicData>
#     <geoData>
#       <address>Ronda de Atocha, 17</address>
#       <zipcode>28012</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.406521900000</latitude>
#       <longitude>-3.695527500000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/hrh_madrid_final_a.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-06-22" id="97202">
#     <basicData>
#       <language>es</language>
#       <name>Hotel Novotel Madrid City Las Ventas </name>
#       <email>H0843@ACCOR.COM</email>
#       <phone>(+34)91 724 76 00</phone>
#       <fax/>
#       <title>Hotel Novotel Madrid City Las Ventas </title>
#       <body>&lt;p&gt;&lt;strong&gt;Novotel Madrid City las Ventas es un hotel dinámico y cosmopolita&amp;nbsp;situado muy cerca del aeropuerto y de IFEMA MADRID y con una estupenda comunicación con&amp;nbsp;Madrid centro.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Sus 156 habitaciones son espaciosas y de diseño contemporáneo. Todas disponen de wifi gratuito, minibar, caja fuerte, hervidor de agua, secador de pelo, artículos de aseo ecológicos y algunas de ellas cafetera Nespresso, albornoz y zapatillas.&lt;/p&gt;&lt;p&gt;Entre sus muchos servicios y comodidades, ofrecen, piscina de verano, gimnasio gratuito para clientes, parking propio (con suplemento), wifi gratuito, restaurante &amp;amp; bar con terraza al aire libre, salas de reunión y aceptan mascotas (con suplemento).&lt;/p&gt;&lt;p&gt;El hotel ofrece también una excelente y sorprendente gastronomía&amp;nbsp;en su restaurante INSOLITO, un concepto diferente que gira en torno a una cocina a la vista al carbón con la mejor materia prima en un ambiente dinámico y acogedor con terraza al aire libre.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/hotel-novotel-madrid-city-ventas</web>
#     </basicData>
#     <geoData>
#       <address>Albacete 1, Esquina Avenida de Badajoz</address>
#       <zipcode>28027</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.441308900000</latitude>
#       <longitude>-3.657559700000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_4.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_3.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_10.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_9.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_7.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_12.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_14.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/calle_de_albacete_1_28027_madrid_spain_16.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/4082-59.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-06-10" id="97116">
#     <basicData>
#       <language>es</language>
#       <name>Pestana CR7 Gran V&amp;iacute;a Madrid</name>
#       <email>guest@pestana.com</email>
#       <phone>917 71 02 40</phone>
#       <fax/>
#       <title>Pestana CR7 Gran V&amp;iacute;a Madrid</title>
#       <body>&lt;p&gt;&lt;strong&gt;La Gran Vía madrileña ha sido enclave escogido para la apertura del primer hotel de Cristiano Ronaldo fuera de Portugal.&amp;nbsp;&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este edificio de 1920 totalmente rehabilitado, cuenta con 168 habitaciones, divididas en nueve categorías y equipadas con las últimas tecnologías y excelentes comodidades y servicios. Como no podía ser de otra forma, el deporte tiene una gran presencia, tanto en su decoración, con camisetas firmadas e imágenes del futbolista, como en sus instalaciones, ya que cuenta con una &lt;em&gt;fitness box&lt;/em&gt; o zona para el deporte. Además, organiza programas de entrenamiento y actividades deportivas.&lt;/p&gt;&lt;p&gt;En la planta 9, abierta a todo el mundo, se encuentra una pizzería&amp;nbsp;con el sello del chef Mauro Soggiu, uno de los fundadores de la que se considera una de las mejores pizzas de NYC, un &lt;em&gt;sport bar&lt;/em&gt; donde poder jugar al futbolín o ver un partido y un espectacular &lt;em&gt;rooftop&lt;/em&gt; con diferentes alturas y una visión 360 del skyline de Madrid.&lt;/p&gt;&lt;p&gt;Cuentan con espacios adaptados para reuniones que se pueden configurar en diferentes disposiciones, con paredes que se convierten en pizarras y salas para videoconferencias.&lt;/p&gt;&lt;p&gt;&lt;br /&gt;&amp;nbsp;&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/pestana-cr7-gran-madrid</web>
#     </basicData>
#     <geoData>
#       <address>Gran Vía, 29 </address>
#       <zipcode>28013</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.419955600000</latitude>
#       <longitude>-3.703284800000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-hotel_0.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-deluxe-corner1.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-cr7-studio7.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-superior-view.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-interior_1.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/grand-via-madrid-fitness-center.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/gran-via-madrid-bar-render_0.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/gran-via-madrid-rooftop-render.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-07-01" id="95433">
#     <basicData>
#       <language>es</language>
#       <name>Four Seasons Hotel Madrid</name>
#       <email/>
#       <phone>(+ 34) 910 88 33 33</phone>
#       <fax/>
#       <title>Four Seasons Hotel Madrid</title>
#       <body>&lt;p&gt;&lt;strong&gt;Four Seasons Hotel Madrid está ubicado en el Complejo Canalejas, un espacio reformado de más de&amp;nbsp;50 000 m2 donde anteriormente se situaban siete edificios históricos pertenecientes a antiguos bancos. De ellos, se conservan más de 3700 artefactos y elementos originales que han sido restaurados y reinstalados, incluso cinco cajas fuertes que pertenecieron a las diferentes entidades bancarias sirven ahora como vitrinas de exposición de joyas, excepto una de ellas, que será la entrada al hotel.&amp;nbsp;En este mismo espacio también se encuentran 22 residencias privadas Four Seasons y la Galería Canalejas, un concepto de galería comercial y gastronomía único.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este alojamiento de cinco estrellas cuenta con 200 habitaciones y suites, todas muy espaciosas y con magníficas vistas sobre las calles más céntricas de la ciudad. Algunas de ellas están diseñadas en dos niveles conectados por una pequeña escalera o cuentan con balcones o amplias terrazas privadas, ideales para disfrutar del clima de Madrid. Además, cuenta con una piscina interior, gimnasio 24 h., salón de belleza, obras de arte contemporáneo por todo el hotel y un &lt;a href=&quot;https://www.esmadrid.com/deporte/spa-hotel-four-seasons&quot;&gt;&lt;strong&gt;spa&lt;/strong&gt; &lt;/a&gt;de lujo con cuatro niveles,&amp;nbsp;entre otras muchas más comodidades y servicios.&lt;/p&gt;&lt;p&gt;En la azotea y con un estupendo &lt;em&gt;skyline&lt;/em&gt; de fondo, se encuentra el &lt;a href=&quot;https://www.esmadrid.com/restaurantes/dani-brasserie&quot; target=&quot;_blank&quot;&gt;restaurante &lt;/a&gt;&lt;strong&gt;&lt;a href=&quot;https://www.esmadrid.com/restaurantes/dani-brasserie&quot; target=&quot;_blank&quot;&gt;Dani&lt;/a&gt;,&lt;/strong&gt; dirigido por, el&amp;nbsp;galardonado con tres estrellas Michelin, &lt;strong&gt;Dani García&lt;/strong&gt;, una &lt;em&gt;brasserie&lt;/em&gt; que ofrece una combinación de platos elegantes, característicos de su restaurante con estrellas Michelin, con platos típicos de la cocina andaluza tradicional.&lt;/p&gt;&lt;p&gt;Distribuídos en la primera planta&amp;nbsp;y en el&lt;em&gt; lobby &lt;/em&gt;de hotel cuenta&amp;nbsp;con dos espacios gastronómicos más:&amp;nbsp;&lt;strong&gt;Isa&lt;/strong&gt;, con modernas tapas asiáticas, platos pequeños, cocina tradicional y todo tipo de cócteles y &lt;strong&gt;El Patio&lt;/strong&gt;, ubicado en el antiguo patio de operaciones del Banco Central de Crédito, con un menú que incluye grandes clásicos y una amplia selección de dulces y tartas caseras, café recién molido y tés, así como una deliciosa adaptación de los famosos &lt;em&gt;afternoon teas&lt;/em&gt; en forma de merienda típica española.&lt;br /&gt;&amp;nbsp;&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/four-seasons-hotel-madrid</web>
#     </basicData>
#     <geoData>
#       <address> de Sevilla, 3, </address>
#       <zipcode>28014</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.417008900000</latitude>
#       <longitude>-3.700388000000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mmd_002.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mmd_006_original.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/mmd_008.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/1_lobby.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/four_seasons_madrid_canalejas_hall_3_-_copia.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/2_deluxe_room.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/3_fourseasonsmadrid_premierterrace_1.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/4_fourseasonsmadrid_fourseasonsterracesuite_1.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/6_fourseasonsmadrid_onebedroomsuite_3.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/fs_madrid_presidential_2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/one_bedroom_terrace_suite.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/7_fourseasonsmadrid_twobedroomsuite_bathroom_2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/9_fourseasonsmadrid_spa_1.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/spa2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/dani_garcia_156_a2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/11_dani_brasserie_082.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/four_seasons_madrid_canalejas_hall_3_-_copia_0.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/four_seasons_madrid_sol_ballroom_5.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/four_seasons_madrid_courtyard_wedding_3_-_copia.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/four_seasons_madrid_gym_-_copia.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7028</item>
#               <item name="SubCategoria">5 estrellas Gran Lujo</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-05-29" id="94629">
#     <basicData>
#       <language>es</language>
#       <name>Apartahotel Las Matas Tartesos</name>
#       <email/>
#       <phone>(+34) 91 640 00 55</phone>
#       <fax/>
#       <title>Apartahotel Las Matas Tartesos</title>
#       <body>&lt;hr /&gt;&lt;p class=&quot;heading-3&quot;&gt;&lt;strong&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/strong&gt;&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&lt;strong&gt;Situados en Las Rozas, localidad del oeste de la Comunidad de Madrid, se encuentran estos apartamentos totalmente equipados, cuyas zonas comunes también incluyen un gimnasio de uso gratuito, salas para banquetes y reuniones (previo pago), bar y lavandería.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Los estudios están totalmente equipados, con aire acondicionado, calefacción y wifi. Disponen de zona de estar con televisión, baño privado con artículos de aseo, y cocina con nevera, vajilla y cubertería. En todos los estudios hay dos camas individuales. El aparcamiento privado es gratuito.&lt;/p&gt;&lt;p&gt;Los apartamentos se encuentran a 100 metros de la autopista A &amp;ndash; 6, y a 1 km de la estación de tren de Pinar de Las Rozas.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/apartahotel-matas-tartesos</web>
#     </basicData>
#     <geoData>
#       <address>Pollensa, 5</address>
#       <zipcode>28230</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.531696400000</latitude>
#       <longitude>-3.890689000000</longitude>
#       <subAdministrativeArea>Las Rozas</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/aparthotel_tartesos.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7042</item>
#           <item name="Categoria">Apartahoteles</item>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-04-23" id="94628">
#     <basicData>
#       <language>es</language>
#       <name>Hotel Las Gacelas</name>
#       <email>reservas@hotel-lasgacelas.com</email>
#       <phone>(34) 918 538 000</phone>
#       <fax/>
#       <title>Hotel Las Gacelas</title>
#       <body>&lt;hr /&gt;&lt;p class=&quot;heading-3&quot;&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&amp;nbsp;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;En plena naturaleza, en el corazón de la Sierra de Guadarrama y a tan solo 45 kms de Madrid, se encuentra el Hotel Las Gacelas.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este alojamiento ofrece 3 tipos de habitaciones: habitación doble, junior suite y suite noble, todas ellas decoradas con detalles de madera y piedra acordes con el ambiente rural donde se encuentran. El hotel dispone de piscina, pistas de pádel y frontón, dos parkings exclusivos para los clientes totalmente gratuito, además de un restaurante de cocina meditarránea y tradicional.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/hotel-gacelas</web>
#     </basicData>
#     <geoData>
#       <address>de San Sebastián, 53</address>
#       <zipcode>28490</zipcode>
#       <locality>Becerril de la Sierra</locality>
#       <country>Spain</country>
#       <latitude>40.710999500000</latitude>
#       <longitude>-3.994158000000</longitude>
#       <subAdministrativeArea>Navacerrada</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/las_gacelas.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/hotel_las_gacelas_2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/hotel_las_gacelas_3.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/hotel_las_gacelas_6.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7025</item>
#               <item name="SubCategoria">3 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-04-22" id="94627">
#     <basicData>
#       <language>es</language>
#       <name>Apartamentos Plaza de Santiago</name>
#       <email>reservas@apartamentosplazadesantiago.com</email>
#       <phone>(+34) 91 691 55 00</phone>
#       <fax/>
#       <title>Apartamentos Plaza de Santiago</title>
#       <body>&lt;hr /&gt;&lt;div&gt;&lt;p class=&quot;heading-3&quot;&gt;&lt;strong&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/strong&gt;&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&lt;strong&gt;Este edificio de 45 apartamentos turísticos, totalmente renovado y con una fachada del siglo XIX,&amp;nbsp;se encuentra situado en el centro de Pinto, localidad del sur de Madrid, y a tan sólo 300 metros de la estación de cercanías de Renfe, con una línea directa a la Puerta del Sol. Cuenta con 35 estudios dobles, 8 estudios abuhardillados con terraza y 2 suites familiares con terraza.&lt;/strong&gt;&lt;/p&gt;&lt;/div&gt;&lt;p&gt;Los apartamentos disponen de baño propio y cocina completa, así como de la posibilidad de hacer uso del servicio de lavandería, previo pago. Se realiza una limpieza semanal con cambio de sábanas y toallas.&lt;/p&gt;&lt;p&gt;Cerca del inmueble también está el autobús lanzadera al Parque Warner, que en coche se encuentra a 10 minutos, al igual que la sede central de Airbus, o el Centro Comercial Nassica Style Outlet.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/apartamentos-plaza-santiago</web>
#     </basicData>
#     <geoData>
#       <address>de Santiago, 3</address>
#       <zipcode>28320</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.245518600000</latitude>
#       <longitude>-3.700417400000</longitude>
#       <subAdministrativeArea>Pinto</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_plaza_santiago.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_plaza_santiago_2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_plaza_santiago_4.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_plaza_santiago_3.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7042</item>
#           <item name="Categoria">Apartahoteles</item>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-04-23" id="94626">
#     <basicData>
#       <language>es</language>
#       <name>Apartahotel TH Las Rozas</name>
#       <email>reservas@thlasrozashotel.com</email>
#       <phone>(34) 916 37 09 00</phone>
#       <fax/>
#       <title>Apartahotel TH Las Rozas</title>
#       <body>&lt;hr /&gt;&lt;p class=&quot;heading-3&quot;&gt;&lt;br /&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&lt;strong&gt;Ubicado a 7 km de las Rozas y a menos de 20 km de Madrid, el ApartaHotel TH Las Rozas cuenta con apartamentos de 1 dormitorio&amp;nbsp;para 2 o 3 personas y habitaciones dobles y triples.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;&lt;br /&gt;Todas sus habitaciones y apartamentos estan equipados con aire acondicionado, calefacción, TV vía satélite, escritorio, zona de estar y baño elegante. Dispone de recepción de 24 horas y máquinas expendedoras. También ofrece un desayuno buffet y conexión WiFi gratuita.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/apartahotel-th-rozas</web>
#     </basicData>
#     <geoData>
#       <address>Camino Viejo de Madrid, 38</address>
#       <zipcode>28230</zipcode>
#       <locality>Las Rozas</locality>
#       <country>Spain</country>
#       <latitude>40.484121100000</latitude>
#       <longitude>-3.856662800000</longitude>
#       <subAdministrativeArea>Las Rozas</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas_2.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas_3.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas_5.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas_1.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/th_las_rozas4.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7042</item>
#           <item name="Categoria">Apartahoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7045</item>
#               <item name="SubCategoria">3 llaves</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-04-23" id="94625">
#     <basicData>
#       <language>es</language>
#       <name>Apartamentos Suites Florida</name>
#       <email>info@apartamentossuitesflorida.es</email>
#       <phone>(34) 91 748 20 21 </phone>
#       <fax/>
#       <title>Apartamentos Suites Florida</title>
#       <body>&lt;hr /&gt;&lt;p class=&quot;heading-3&quot;&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&lt;strong&gt;En un enclave estratégico, junto a la M-40, próximo al aeropuerto y a IFEMA, y a menos de 15 km del centro histórico de Madrid, se encuentra esta urbanización cerrada.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Este alojamiento esta&amp;nbsp;compuesto&amp;nbsp;por 4 bloques con un total de 325 apartamentos (240 de 1 dormitorio, 85 de 2 dormitorios),&amp;nbsp;zonas ajardinadas, piscina, pista de padel, parque infantil, WIFI gratuito y plazas de garaje lo que le convierte en un lugar ideal tanto para periodos vacacionales, viajes de trabajo o larga duración.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/apartamentos-suites-florida</web>
#     </basicData>
#     <geoData>
#       <address>Campezo, 2. Pol. Ind. Las Mercedes </address>
#       <zipcode>28022</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.449062300000</latitude>
#       <longitude>-3.582653300000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_florida.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_florida_2.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_florida3.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_florida_0.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_florida_1.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias/>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2020-04-23" id="94624">
#     <basicData>
#       <language>es</language>
#       <name>Apartamentos Suites Aeropuerto</name>
#       <email>info@apartamentossuitesaeropuerto.es</email>
#       <phone>(34) 917 48 067</phone>
#       <fax/>
#       <title>Apartamentos Suites Aeropuerto</title>
#       <body>&lt;hr /&gt;&lt;p class=&quot;heading-3&quot;&gt;Este alojamiento forma parte de los hoteles de guardia de la Comunidad de Madrid considerados como servicio esencial según la Orden TMA/305/2020 de 30 de marzo, del Ministerio de Transportes, Movilidad y Agenda Urbana.&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&amp;nbsp;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;En una situación estratégica, junto a la M-40, próximo al aeropuerto y a IFEMA, y a&amp;nbsp;menos de 15 km del centro histórico de Madrid, se encuentran este conjunto de 300 apartamentos.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Cuentan con viviendas de de 1 ó 2 dormitorios provisto de zonas ajardinadas, piscina, gimnasio, WIFI gratuito y plazas de garaje, además ofrecen servicio de shuttle desde el aeropuerto.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/apartamentos-suites-aeropuerto</web>
#     </basicData>
#     <geoData>
#       <address>Campezo, 8. Pol. Ind. Las Mercedes </address>
#       <zipcode>28022</zipcode>
#       <locality>Madrid</locality>
#       <country>Spain</country>
#       <latitude>40.446415000000</latitude>
#       <longitude>-3.583444300000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_aeropuerto_2_0.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartmento_suites_aeropuerto_5.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_aeropuerto.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/apartamentos_suites_aeropuerto_1.png</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias/>
# ...
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/ac_feria_8.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/ac_feria_9.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/ac_feria_10.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2018-07-09" id="67399">
#     <basicData>
#       <language>es</language>
#       <name>Villa Real</name>
#       <email>villareal@derbyhotels.com</email>
#       <phone>(+34) 91 420 37 67</phone>
#       <fax/>
#       <title>Villa Real</title>
#       <body>&lt;p&gt;&lt;strong&gt;Un hotel de exquisito trato, refugio ideal tras una jornada de ocio o de trabajo, situado junto al Parlamento y a solo cinco minutos del Museo del Prado, el Reina Sofía y el Museo Thyssen Bornemisza. El Villa Real conserva el gusto por lo clásico y guarda en su interior una de las mejores colecciones privadas de mosaicos romanos y &lt;strong&gt;vasos apulios de Grecia&lt;/strong&gt;. &lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Edificado en el siglo XIX, el edificio ha sufrido varias transformaciones hasta el día de hoy. Desde sus terrazas, con unas vistas privilegiadas, pueden apreciarse joyas como el parque del Retiro y el Jardín Botánico. En sus habitaciones de gran lujo, decoradas con muebles del siglo XIX, telas francesas, mármol de Carrara y tarima sueca, se respira un ambiente cálido, confortable y discreto. El hotel dispone de dos restaurantes que han sido reconocidos en los últimos años con distintos galardones, el &lt;strong&gt;East 47&lt;/strong&gt;, donde se puede disfrutar de la mejor cocina de autor junto a las obras originales de Warhol, y el &lt;strong&gt;Restaurante Europa&lt;/strong&gt;, con cocina internacional y de mercado.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/villa-real</web>
#     </basicData>
#     <geoData>
#       <address>Plaza de las Cortes, 10 Madrid 28014 España</address>
#       <zipcode>28014</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.415527000000</latitude>
#       <longitude>-3.696989000000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/villa_real.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/villa_real_2.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/villa_real_3.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Villa_Real1_alta.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7027</item>
#               <item name="SubCategoria">5 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-08-18" id="67374">
#     <basicData>
#       <language>es</language>
#       <name>AC Hotel Cuzco</name>
#       <email>accuzco@ac-hotels.com</email>
#       <phone>(+34) 91 556 06 00</phone>
#       <fax/>
#       <title>AC Hotel Cuzco</title>
#       <body>&lt;p&gt;&lt;strong&gt;El AC Cuzco es un hotel perfecto para los aficionados al fútbol que vienen a la ciudad a ver un partido del Real Madrid y aprovechan esta excusa para pasar un fin de semana en la capital, pues se encuentra a solo unos metros del Santiago Bernabéu y a la vez muy bien comunicado con el centro histórico a través de la red de metro, ya que la estación&amp;nbsp;de Cuzco está situada justo al lado del hotel. Además, la parada de tren de&amp;nbsp;Chamartín está a solo dos kilómetros de distancia.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Para el resto de la semana, este cuatro estrellas es ideal para viajeros de negocios, ya que se ubica justo en el centro de la zona financiera y de negocios. Su oferta pasa por una decoración elegante y sofisticada, tecnologías modernas, como TV de plasma de 32 pulgadas con canales vía satélite e internacionales, un desayuno bufé de alta calidad y un estupendo catálogo de&amp;nbsp;platos internacionales preparados con productos frescos y de estación para el almuerzo y la cena. Asimismo, el AC Lounge ofrece una gran variedad de cócteles y refrigerios. Cuenta con conexión Wi-Fi gratuita las 24 horas al día en todas las habitaciones y zonas comunes y el servicio de habitaciones también se encuentra disponible todo el día.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/ac-hotel-cuzco</web>
#     </basicData>
#     <geoData>
#       <address>Castellana, 133</address>
#       <zipcode>28046</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.458709500000</latitude>
#       <longitude>-3.690567500000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-entrance-0089-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-lobby-0090-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-guestroom-0098-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-superior-2779-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-twin-2776-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-bathroom-0097-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-fitness-0118-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-lounge-0113-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-bar-0116-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-workspace-0111-hor-clsc.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/madcu-forum-0120-hor-clsc.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-08-13" id="67373">
#     <basicData>
#       <language>es</language>
#       <name>AC Aravaca</name>
#       <email>acaravaca@ac-hotels.com</email>
#       <phone>(+34) 91 740 06 80</phone>
#       <fax/>
#       <title>AC Aravaca</title>
#       <body>&lt;p&gt;&amp;nbsp;&lt;/p&gt;&lt;hr /&gt;&lt;p class=&quot;heading-2&quot;&gt;Cerrado temporalmente&lt;/p&gt;&lt;hr /&gt;&lt;p&gt;&amp;nbsp;&lt;/p&gt;&lt;p&gt;&lt;strong&gt;El AC Aravaca es un hotel ideal si lo que se quiere es desconectar del bullicio de la gran ciudad y disfrutar de un ambiente tranquilo y acogedor. Se sitúa en la zona del camino de la Zarzuela, delante de la clínica de la Zarzuela, aunque bien conectado con el centro, para los que vengan a visitar la ciudad, y con la zona de negocios del noroeste, para los que vienen por motivos de trabajo.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;En los alrededores, este cuatro estrellas ofrece posibilidades para todos los gustos. A los que les gusta disfrutar del campo y la naturaleza tienen la Casa de Campo. Y los que prefieren las compras, el cine o comer en un restaurante para pasar su tiempo libre, tienen el centro comercial Sexta Avenida. El hotel cuenta, además, con restaurante para desayunos y cenas, y con un baño turco para los que prefieran no moverse del edificio.&lt;/p&gt;&lt;p&gt;&amp;nbsp;El hotel es 100% libre de humo.&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/ac-aravaca</web>
#     </basicData>
#     <geoData>
#       <address>Zarzuela, 3</address>
#       <zipcode>28023</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.464527000000</latitude>
#       <longitude>-3.784803000000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/AC_Aravaca0_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/AC_Aravaca1_alta.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7026</item>
#               <item name="SubCategoria">4 estrellas</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
#   <service fechaActualizacion="2021-09-24" id="67395">
#     <basicData>
#       <language>es</language>
#       <name>Puerta Am&amp;eacute;rica</name>
#       <email>hotel.puertamerica@hoteles-silken.com</email>
#       <phone>(+34) 91 744 54 00</phone>
#       <fax/>
#       <title>Puerta Am&amp;eacute;rica</title>
#       <body>&lt;p&gt;&lt;strong&gt;Además de un hotel de gran lujo y un símbolo de modernidad, el Hotel Puerta de América supone un espacio de encuentro donde se unen distintas culturas y formas de entender la arquitectura y el diseño.&lt;/strong&gt;&lt;/p&gt;&lt;p&gt;Inaugurado en 2006, su construcción puso manos a la obra a diecinueve de los mejores estudios de arquitectos y diseñadores del mundo, de trece nacionalidades diferentes que han jugado con distintos materiales, colores y formas para crear distintos espacios que reúnen lo mejor del diseño y la arquitectura de vanguardia y donde todos ellos han podido dar rienda suelta a su libertad creativa.&lt;/p&gt;&lt;p&gt;La idea era crear un hotel único en el mundo que aunara distintos modos de ver la arquitectura, el diseño y el arte, y para ello se recurrió a reconocidas figuras como Jean Nouvel, responsable además de la última planta de la llamativa fachada, Javier Mariscal y Fernando Salas, Richard Gluckman, Victorio &amp;amp; Lucchino, Norman Foster o Zaha Hadid, entre otros. El resultado es originalidad, lujo, innovación y libertad formal en un hotel eminentemente ecléctico, en el que el visitante puede descubrir un universo de creación bien distinto en cada visita.&lt;/p&gt;&lt;p&gt;&lt;iframe frameborder=&quot;0&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/ZtQtbgX5TO0&quot; title=&quot;YouTube video player&quot; width=&quot;560&quot;&gt;&lt;/iframe&gt;&lt;/p&gt;</body>
#       <web>http://www.esmadrid.com/alojamientos/puerta-america</web>
#     </basicData>
#     <geoData>
#       <address>América, 41</address>
#       <zipcode>28002</zipcode>
#       <locality/>
#       <country>Spain</country>
#       <latitude>40.440254000000</latitude>
#       <longitude>-3.670216000000</longitude>
#       <subAdministrativeArea>Madrid</subAdministrativeArea>
#     </geoData>
#     <multimedia>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/SilkenPuertadeAmerica1_1404822681.366.png</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America16_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America5_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America8_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America9_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America13_alta.jpg</url>
#       </media>
#       <media type="image">
#         <description/>
#         <url>http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/Silken_Puerta_de_America17_alta.jpg</url>
#       </media>
#     </multimedia>
#     <extradata>
#       <item name="idTipo">3</item>
#       <item name="Tipo">Alojamientos</item>
#       <categorias>
#         <categoria>
#           <item name="idCategoria">7022</item>
#           <item name="Categoria">Hoteles</item>
#           <subcategorias>
#             <subcategoria>
#               <item name="idSubCategoria">7028</item>
#               <item name="SubCategoria">5 estrellas Gran Lujo</item>
#             </subcategoria>
#           </subcategorias>
#         </categoria>
#       </categorias>
#       <item name="Servicios de pago"/>
#       <item name="Horario"/>
#       <fechas/>
#     </extradata>
#   </service>
# </serviceList>

# %% [markdown]
# __Ejercicio 1 [5 puntos]__
#
# Se pide mostrar al usuario un listado de los nombres de los alojamientos que contiene el archivo con el objetivo de que elija un alojamiento y se le muestre de forma amigable(sin etiquetas) por pantalla la información asociada al alojamiento que se encuentra en el fichero recuperado:
#
# * Nombre del alojamiento: etiqueta name
# * Email: etiqueta email
# * Teléfono: etiqueta phone
# * Descripción: etiqueta body
# * Página web: etiqueta web
# * Dirección: etiqueta address, etiqueta zipcode, etiqueta locality
#
#
# A continuación se le pedira si quiere ver fotos del alojamiento, en tal caso se le mostrarán las fotos recuperadas del alojamiento. Para mostrar las imagenes puedes usar un trozo de código similar al siguiente.

# %%
img_src = 'http://www.esmadrid.com/sites/default/files/recursosturisticos/alojamientos/oxigen_hostle.png'
from skimage import io
image = io.imread(img_src)
io.imshow(image)
io.show()

# %% [markdown]
# Observar:
#   * Algunas etiquetas podrían estar vacías o no aparecer. En estos casos, simplemente se mostrará vacío o con la palabra "Desconocido".
#   * Hay que limpiar el texto de la descripción eliminando los símbolos especiales del tipo "&lt;/p&gt;&lt;p&gt;" que aparecen en el mismo.
#
# Por ejemplo si el usuario hubiera elegido el alojamiento "Oxygen Hostel" debería mostrarse por pantalla:
#
# __Nombre del alojamiento:__
#
# Oxygen Hostel
#
# __Descripción:__
#
# En una inmejorable situación, muy cerca de Atocha y del Paseo del Arte, se encuentra este hotel cápsula, el primero en ofrecer un estilo de alojamiento futurista y low cost en Madrid.Disponen de 22 cápsulas, 10 dobles y 12 sencillas, todas equipadas con baños individuales independientes, aire acondicionado y WiFi. Además, ofrecen la posibilidad de trabajar en ellas.Cuentan con dos zonas comunes, salón y cocina, recepción 24 horas y organizan excursiones.No admiten mascotas.
#
# __Página web:__
#
# http://www.esmadrid.com/alojamientos/oxygen-hostel
#
# __Email:__
#
# oxygenmadrid19@gmail.com
#
# __Teléfono:__
#
# +34 686 81 12 61
#
# __Localización:__
#
# Rafael Riego, 19. Madrid 28045

# %%
from os import system, name
from xml.etree import ElementTree
from xml.dom import minidom
import html
import re
from skimage import io

def prettify(elem):
    """Return a pretty-printed XML string for the Element."""
    rough_string=ElementTree.tostring(elem,"utf-8")
    reparsed=minidom.parseString(rough_string)
    return reparsed.toprettyxml(indent="  ")

CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
def cleanhtml(raw_html):
    cleantext = re.sub(CLEANR, '', raw_html)
    return cleantext

f=open("alojamientos_v1_es.xml","rt",encoding="utf8")
arbol=ElementTree.parse(f)

# %%
#Devuelve una lista con el nombre de los alojamientos
def get_ListAlojamientos():
    alojamientosList = list()
    for nodo in arbol.iter("name"):
        alojamientosList.append(html.unescape(nodo.text))
    return alojamientosList


# Devuelve la info asocciada al nombre de un alojamiento
# Nombre del alojamiento: etiqueta name
# Email: etiqueta email
# Teléfono: etiqueta phone
# Descripción: etiqueta body
# Página web: etiqueta web
# Dirección: etiqueta address, etiqueta zipcode, etiqueta locality
def get_Info(alojamiento, root):
    full_info=[]
    for i in range(len(root)):
        if html.unescape(root[i][0][1].text) in alojamiento:
            try : # Comprobar si tiene atributo estrellas
                stars=html.unescape(str(root[i][3][2][0][2][0][1].text))
            except:
                stars="None"
            try:
                categoria=html.unescape(str(root[i][3][2][0][1].text))
            except:
                categoria="None"
            
            # Solo limpiamos el html de los campos que sean caracteres, no numeros
            # Usamos str() para encapsular aquellas etiquetas vacias y usar el string None que devuelve
            dicty = {
                "name": html.unescape(str(root[i][0][1].text)),
                "email": html.unescape(str(root[i][0][2].text)),
                "estrellas": stars,
                "tipo": html.unescape(str(root[i][3][1].text)),
                "categoria": categoria,
                "telefono": str(root[i][0][3].text),
                "descripcion": cleanhtml(html.unescape(str(root[i][0][6].text))),
                "web": html.unescape(str(root[i][0][7].text)),
                "address": html.unescape(str(root[i][1][0].text)),
                "zipcode": str(root[i][1][1].text),
                "locality": html.unescape(str(root[i][1][2].text)),
                "latitude": str(root[i][1][4].text),
                "longitude": str(root[i][1][5].text)
            }
            
            multimedia = list()
            for img in root[i][2]:
                multimedia.append(html.unescape(str(img[1].text)))
                
            full_info = [dicty, multimedia]
            i = len(root) # end loop
            
    return full_info

# Muestra por pantalla la info asociada a un establecimiento
def print_info(alojamiento):
    # Imprimir la info básica
    print('\033[1m'+"Nombre del alojamiento:\n"+'\033[0m')
    print(alojamiento[0]["name"] + "\n")
    print('\033[1m'+"Descripción:\n"+'\033[0m')
    print(alojamiento[0]["descripcion"] + "\n")
    print('\033[1m'+"Página web:\n"+'\033[0m')
    print(alojamiento[0]["web"] + "\n")
    print('\033[1m'+"Email:\n"+'\033[0m')
    print(alojamiento[0]["email"] + "\n")
    print('\033[1m'+"Teléfono:\n"+'\033[0m')
    print(alojamiento[0]["telefono"] + "\n")
    print('\033[1m'+"Localización:\n"+'\033[0m')
    print(alojamiento[0]["address"]+".",alojamiento[0]["locality"],alojamiento[0]["zipcode"] + "\n")
    
    # Imprimir multimedia en demanda
    select = input("¿Desea ver fotos del establecimiento? (s/n): ").lower()
    if select == "s":
        for img_src in alojamiento[1]:
            image = io.imread(img_src)
            io.imshow(image)
            io.show()

# Imprime una lista con los nombres de los hoteles
def print_alojamientos(lista_alojamientos):
    i = 1
    for kelo in lista_alojamientos:
        print(i, "-", kelo)
        i += 1

# [service][basicData/geodata/multimedia/extradata][nombres...]

# %%
def func1(lista_aloj):
    if lista_aloj:
        print_alojamientos(lista_aloj)
        select = int(input("Seleccione un alojamiento (0 -> Salir): "))
            
        while select > 0:
            if select > 0:
                root=arbol.getroot()
                info_alojamiento=get_Info(lista_aloj[select-1], root)
                print("\n")
                print_info(info_alojamiento)
            
            select = input("¿Desea ver más alojamientos? (s/n): ").lower()
            
            if select == "s":
                print_alojamientos(lista_aloj)
                select = int(input("Seleccione un alojamiento (0 -> Salir): "))
            else:
                select = 0
    else:
        print("No hay ningun alojamiento disponible. \n")

# %%
lista_alojamientos = get_ListAlojamientos()
func1(lista_alojamientos)
# Out:
# 1 - Oxygen Hostel
# 2 - Canopy by Hilton Madrid Castellana
# 3 - Atocha Hotel Madrid, Tapestry Collection by Hilton
# 4 - Hard Rock Hotel Madrid
# 5 - Hotel Novotel Madrid City Las Ventas
# 6 - Pestana CR7 Gran Vía Madrid
# 7 - Four Seasons Hotel Madrid
# 8 - Apartahotel Las Matas Tartesos
# 9 - Hotel Las Gacelas
# 10 - Apartamentos Plaza de Santiago
# 11 - Apartahotel TH Las Rozas
# 12 - Apartamentos Suites Florida
# 13 - Apartamentos Suites Aeropuerto
# 14 - Tryp Madrid Airport Suites
# 15 -  Room Mate Macarena
# 16 - Hotel Riu Plaza España
# 17 - Bluesock Madrid
# 18 - Aloft Gran Vía Madrid
# 19 - Pestana Plaza Mayor
# 20 - B&B Hotel Madrid Centro Puerta del Sol
# 21 - CoolRooms Atocha
# 22 - Heritage Madrid Hotel
# 23 - Generator Hostel Madrid
# 24 - Hotel Icon Casona 1900 by Petit Palace
# 25 - Poshtel LaNave
# 26 - NH Collection Madrid Gran Vía
# 27 - Barceló Imagine
# 28 - Plaza España Skyline by Bemate
# 29 - Gran Hotel Inglés
# 30 - VP Plaza España Design
# 31 - Hotel Dome Madrid
# 32 - Vitium Urban Suites
# 33 - Bungalows Camping Alpha Madrid
# 34 - Hyatt Centric Gran Vía Madrid
# 35 - La Casa de los Horrores
# 36 - Axel Hotel Madrid
# 37 - Hotel Círculo Gran Vía, Autograph Collection
# 38 - Barceló Torre de Madrid
# 39 - Ibis Madrid Centro Las Ventas
# 40 - The Walt Madrid
# 41 - DoubleTree by Hilton Madrid - Prado
# 42 - Tótem Madrid
# 43 - Vincci The Mint
# 44 - Only You Hotel Atocha
# 45 - Eurostars Central
# 46 - Novotel Madrid Center
# 47 - Dear Hotel
# 48 - Castilla II
# 49 - DormirDcine
# 50 - NH Madrid Alonso Martínez
# 51 - The Hat
# 52 - URSO Hotel & Spa Madrid
# 53 - One Shot 04
# 54 - Hotel Indigo
# 55 - One Shot Luchana 22
# 56 - One Shot Prado 23
# 57 - Safestay Madrid
# 58 - La posada de El Chaflán
# 59 - Senator Barajas
# 60 - NH Collection Madrid Suecia
# 61 - Exe Moncloa
# 62 - Only You Boutique Hotel Madrid
# 63 - Hotel Travelodge Madrid Alcalá
# 64 - Holiday Inn Madrid - Calle Alcalá
# 65 - Eurostars Plaza Mayor
# 66 - Lapepa Chic B&B
# 67 - Hotel Sardinero Madrid
# 68 - Artistic B&B
# 69 - Artrip Hotel
# 70 - Hotel Petit Palace Lealtad Plaza
# 71 - Hotel Petit Palace Savoy Alfonso XII
# 72 - Hotel Petit Palace Santa Bárbara
# 73 - La Posada del Dragón
# 74 - Catalonia Plaza Mayor
# 75 - Catalonia Atocha
# 76 - Hotel NH Ribera del Manzanares
# 77 - Posada del León de Oro
# 78 - Hotel NH Collection Madrid Palacio de Tepa
# 79 - Suites 33
# 80 - SHS Aeropuerto
# 81 - Barajas Plaza
# 82 - Hotel  Nuevo Boston
# 83 - Agora Juan de Austria
# 84 - Crowne Plaza Madrid Airport
# 85 - Tach by Clement Hoteles
# 86 - AC Atocha
# 87 - Hotel Santo Domingo
# 88 - Hostal Gala
# 89 - Espahotel Gran Vía
# 90 - The Principal Madrid Hotel
# 91 - Radisson Blu Hotel, Madrid Prado
# 92 - Mayerling
# 93 - Urban Sea Atocha 113
# 94 - Axor Barajas Plus
# 95 - Axor Feria
# 96 - Oxum
# 97 - Mirador de Chamartín
# 98 - Apartosuites Jardines de Sabatini
# 99 - Suites Barrio de Salamanca
# 100 - Felipe V
# 101 - Splendid
# 102 - Ártico
# 103 - Los Ángeles
# 104 - Aparthotel Encasa
# 105 - Hotel Único
# 106 - Playa
# 107 - Rofer
# 108 - Rico
# 109 - Pensión Stella
# 110 - Santa Bárbara
# 111 - Patria
# 112 - Matheu
# 113 - Hostal Pacios
# 114 - Hostal Oriente
# 115 - Casa de huéspedes La Muralla
# 116 - Naranjos I
# 117 - Pensión Mollo
# 118 - Marlasca
# 119 - Mendoza
# 120 - Mayrit (Hostal Ivor y Hostal Mayrit )
# 121 - Hostal Miguel Ángel
# 122 - Los Perales
# 123 - Guerra
# 124 - Hostal Horizonte
# 125 - Internacional
# 126 - Alojamiento Jaén
# 127 - Las Fuentes
# 128 - El Pasaje
# 129 - Faustino
# 130 - El Catalán
# 131 - Edreira
# 132 - Conchita II
# 133 - Abami 2
# 134 - Domínguez
# 135 - Aresol
# 136 - Hostal Biarritz
# 137 - Hostal Chelo
# 138 - Pensión Corbero
# 139 - Florida
# 140 - Hostal del Pez Azul
# 141 - Hispalense
# 142 - Pensión Berti
# 143 - Pensión Cartagenera
# 144 - Pensión Barja
# 145 - Hostal Bahía Madrid
# 146 - Pensión Casado
# 147 - Casa de Huespedes Casillas
# 148 - Pensión Numancia
# 149 - Pensión Adeco
# 150 - Angelines
# 151 - Alaska
# 152 - Jardín Real de Mirasierra
# 153 - Ilunion Hotels Atrium
# 154 - Los Coronales
# 155 - Apartamentos Madrid
# 156 - Compostela Suites
# 157 - NH Las Tablas
# 158 - Villa Magna
# 159 - Hotel Eco Vía Lusitana
# 160 - Eurostars Madrid Tower
# 161 - Petit Palace Mayor-Plaza
# 162 - Hostal Odesa
# 163 - Hostal Dos Naciones
# 164 - Hotel Julia
# 165 - Hilton Madrid Airport
# 166 - Maydrit
# 167 - Apartamentos Ramón de la Cruz
# 168 - Ibis Calle Alcalá Hotel
# 169 - Eco Alcalá Suites
# 170 - B & B Hotel Madrid Airport
# 171 - Suites Viena
# 172 - Hostal Colors Host
# 173 - Adriá Santa Ana
# 174 - Armesto
# 175 - Barceló Castellana Norte
# 176 - Room Mate Laura
# 177 - Hostal la Fontana
# 178 - Hostal Puerta del Sol
# 179 - Pizarro
# 180 - Room Mate Óscar
# 181 - Cats Hostel Madrid Sol
# 182 - Apartamentos Juan Bravo
# 183 - Albergue MuchoMadrid
# 184 - Cats Chill Out Hostel
# 185 - Albergue Barbieri International
# 186 - San Fermín
# 187 - Hostel Los Amigos
# 188 - Albergue Internacional Posada de Huertas
# 189 - Residencia Universitaria Cardenal Spinola
# 190 - Residencia U. Nuestra Señora del Rosario
# 191 - Residencia U. Siervas del Sagrado Corazón
# 192 - Residencia Universitaria Virgen de las Nieves
# 193 - Apartamentos Centro Colón
# 194 - Residencia Universitaria María Inmaculada
# 195 - Aparthotel Serrano Recoletos
# 196 - Apartamentos Olano
# 197 - Apartamentos Principe 11
# 198 - Apartamentos Goya 75
# 199 - The Pavilions Madrid
# 200 - Residencia U. Institución del Divino Maestro
# 201 - Residencias de Postgraduados Pío XI y León XIII
# 202 - Stylish city aparhotel
# 203 - Residencia Universitaria Augustinus-Nebrija
# 204 - Apartahotel VP El Madroño
# 205 - Residencia Universitaria Santísima Trinidad
# 206 - Residencia Universitaria Gómez-Pardo
# 207 - Colegio Mayor Jaime del Amo
# 208 - Club Universitario
# 209 - Colegio Mayor Ximénez de Cisneros
# 210 - Centro Universitario Castilla
# 211 - Colegio Mayor Aquinas
# 212 - Colegio Mayor Pío XII
# 213 - Residencia de Estudiantes EASO
# 214 - Residencia Universitaria Benito Pérez Galdós
# 215 - Aparthotel Th la Florida
# 216 - Residencia Universitaria Porta Coeli
# 217 - Aparthotel Th  Aravaca
# 218 - Aparthotel G3 Galeón
# 219 - Residencia Virgen del Pilar
# 220 - Residencia Universitaria El Pilar
# 221 -  Bluesense Madrid Genova
# 222 - Tagaste Madrid
# 223 - Residencia Universitaria Presentación de María
# 224 - Residencia Universitaria Verbo Encarnado
# 225 - Residencia Universitaria Nebrija-Chamberí
# 226 - Residencia Asociación Católica Internacional
# 227 - Residencia Trinitarias de Madrid
# 228 - Aparthotel Quo Eraso
# 229 - Residencia Santísima Trinidad
# 230 - Residencia Nuestra Señora de Coromoto
# 231 - Colegio Mayor San Pablo
# 232 - Colegio Mayor Antonio de Nebrija
# 233 - Colegio Mayor Santillana
# 234 - Espahotel Plaza Basílica
# 235 - Residencia Universitaria Madre del Divino Pastor
# 236 - Residencia Universitaria Ciudad Escolar
# 237 - Residencia Universitaria Sagrado Corazón
# 238 - Colegio Mayor Nuestra Señora de Guadalupe
# 239 - Residencia Universitaria Erasmo
# 240 - Colegio Mayor Barberán
# 241 - Colegio Mayor Chaminade
# 242 - Residencia Universitaria Sofía Barat
# 243 - Apartamentos Sercotel Esentia Togumar
# 244 - Colegio Mayor Diego de Covarrubias
# 245 - Colegio Mayor Elías Ahúja
# 246 - Muralto Madrid Princesa
# 247 - Colegio Mayor Universitario Mendel
# 248 - Colegio Mayor Fundación SEPI
# 249 - Apartamentos Los Jerónimos
# 250 - Colegio Mayor Juan Luis Vives
# 251 - Colegio Mayor Nuestra Señora de Africa
# 252 - Colegio Mayor Argentino Nuestra Señora de Luján
# 253 - Colegio Mayor Santa María de Europa
# 254 - Colegio Mayor Isabel de España
# 255 - Colegio Mayor Teresa de Jesús
# 256 - Colegio Mayor Mater Salvatoris
# 257 - Colegio Mayor Montalbán
# 258 - Aparthotel Rosales
# 259 - Colegio Mayor Moncloa
# 260 - Colegio Mayor Alcalá
# 261 - Hogar Nuestra Señora del Sagrado Corazón
# 262 - Colegio Mayor Somosierra
# 263 - Aparthotel Tribunal
# 264 - Colegio Mayor Berrospe
# 265 - Colegio Mayor Alcor
# 266 - Colegio Mayor Vedruna
# 267 - Colegio Mayor Santa Mónica
# 268 - Colegio Mayor Santa María del Pino
# 269 - Colegio Mayor Marqués de la Ensenada
# 270 - Colegio Mayor Santa María del Estudiante
# 271 - Colegio Mayor César Carlos
# 272 - Colegio Mayor Casa do Brasil
# 273 - Colegio Mayor Juan XXIII Roncalli
# 274 - Bluesense Madrid Serrano
# 275 - Colegio Mayor Mara
# 276 - Colegio Mayor Zurbarán
# 277 - Colegio Mayor Padre Poveda
# 278 - Espahotel Plaza de España
# 279 - Abalú
# 280 - Colegio Mayor Universitario Loyola
# 281 - Camping Osuna
# 282 - Colegio Mayor San Agustín
# 283 - Colegio Mayor Jorge Juan
# 284 - Hospes Puerta de Alcalá
# 285 - Montecarlo
# 286 - María Luisa
# 287 - María Ronda
# 288 - Hostal la Macarena
# 289 - Lourdes
# 290 - León
# 291 - Milabi
# 292 - Hostal Lido
# 293 - María Cristina
# 294 - Moncloa
# 295 - Jemasaca-Palma 61
# 296 - Josefina
# 297 - Hostal Atocha Almudena Martín
# 298 - Hostal Madrid
# 299 - María del Mar
# 300 - Luis XV
# 301 - López
# 302 - Lisboa
# 303 - Hostal Fuencarral Kryse
# 304 - Hostal Lamalonga
# 305 - Praktik Metropol
# 306 - Lauria
# 307 - Fuente Mar
# 308 - La Perla Asturiana
# 309 - Fernández
# 310 - Persal
# 311 - Pensión Pérez
# 312 - Fuente Sol
# 313 - Flores
# 314 - Falfes
# 315 - París
# 316 - Nuestra Señora de Sonsoles
# 317 - Hostal el Pilar
# 318 - Gonzalo
# 319 - Olga
# 320 - Gallardo
# 321 - Parajas
# 322 - Galaico
# 323 - Ch Galaica
# 324 - Far Home Plaza Mayor
# 325 - Oporto
# 326 - Ginebra
# 327 - Hostal Greco
# 328 - Gran Vía 63 Rooms
# 329 - Hispano
# 330 - Hispano Argentino
# 331 - Nuestra Señora de la Paloma
# 332 - Ibias
# 333 - La Nava
# 334 - Narváez
# 335 - Esmeralda
# 336 - La Prensa
# 337 - Don Pedro
# 338 - Puerta Bonita
# 339 - Principado
# 340 - Prim
# 341 - Don Alfonso
# 342 - Cruz Sol
# 343 - Hostal CC Atocha
# 344 - Palacios
# 345 - Good Rooms
# 346 - Plaza D'ort Rooms
# 347 - JC Rooms Puerta del Sol
# 348 - Riesco
# 349 - Emilio
# 350 - Pretoria
# 351 - Esparteros
# 352 - Prada
# 353 - Dulcinea
# 354 - Don Juan
# 355 - Comercial
# 356 - Riba
# 357 - Woohoo Hostal Madrid
# 358 - Conchita
# 359 - Condestable
# 360 - Continental
# 361 - Rías Bajas
# 362 - Hostal Narvaez Retiro
# 363 - Delfina
# 364 - Velázquez 45 by Pillow
# 365 - Reconquista
# 366 - Rivera
# 367 - Hostal Ballesta
# 368 - Hostal Santo Domingo
# 369 - Sleep'n Atocha
# 370 - Santa Cruz
# 371 - Santa Isabel
# 372 - San Lorenzo
# 373 - Hostal San Isidro
# 374 - San Antonio
# 375 - Hostal Salamanca
# 376 - Rober
# 377 - Hostal Cervantes
# 378 - Breogan y Kryse
# 379 - Bruña
# 380 - Carabanchel
# 381 - San Martín
# 382 - Callao
# 383 - Buenos Aires
# 384 - Sardinero
# 385 - Carrera
# 386 - Santillan
# 387 - Casanova
# 388 - Centro Sol
# 389 - Ruano
# 390 - Castilla I
# 391 - Cervelo
# 392 - Río Paraná
# 393 - Ríos
# 394 - Tijcal II
# 395 - Inter Plaza Mayor
# 396 - Hostal Avenida
# 397 - Barrera
# 398 - Besaya
# 399 - Atocha Almudena Martín
# 400 - Sil & Serranos
# 401 - Benamar
# 402 - Bermejo
# 403 - THC Bergantín hostel
# 404 - El Tera
# 405 - Betanzos
# 406 - La Selecta
# 407 - Bianco
# 408 - Americano
# 409 - Los Alpes
# 410 - Astoria
# 411 - Victoria III
# 412 - Tudescos
# 413 - Las Torres
# 414 - Trevinca
# 415 - Los Arcos
# 416 - Valencia
# 417 - Hostal Alonso
# 418 - La Vera
# 419 - Victoria
# 420 - Triana
# 421 - Victoria II
# 422 - Alhambra Suites
# 423 - Veracruz
# 424 - Aliste
# 425 - Vázquez de Mella
# 426 - América
# 427 - Andorra
# 428 - Hostal Corazón
# 429 - Arrate
# 430 - Tokio
# 431 - Zabala
# 432 - La Zona
# 433 - Villamáñez
# 434 - Hostal Aeropuerto
# 435 - Hostal Atelier
# 436 - Hostal Abril
# 437 - Zamora
# 438 - Hostal Abami
# 439 - Alfaro
# 440 - Hostal Alegría
# 441 - Zamorán
# 442 - Adriano
# 443 - Aguilar
# 444 - Hostal MH Fuencarral
# 445 - Viky
# 446 - Los 5 Pinos
# 447 - 4C Puerta Europa
# 448 - Sancho
# 449 - Apartahotel Marcenado
# 450 - Casual Madrid Del Teatro
# 451 - Gran Legazpi
# 452 - Aquaria Negresco
# 453 - Senator Castellana
# 454 - Acta Madfor
# 455 - Don Luis
# 456 - Moderno
# 457 - Francisco I
# 458 - Europa
# 459 - Caballero Errante
# 460 - Ibis Madrid Aeropuerto Barajas
# 461 - Ganivet
# 462 - Mora
# 463 - Ibis Madrid Centro
# 464 - Isis
# 465 - Mediodía
# 466 - México
# 467 - Hotel Plaza Mayor
# 468 - NH Madrid Barajas Airport
# 469 - Neo Magna
# 470 - Di Carlo
# 471 - Concordy
# 472 - Room Mate Mario
# 473 - Sterling
# 474 - Hotel Asturias
# 475 - 4C Bravo Murillo
# 476 - Érase un Hotel
# 477 - Petit Palace Ducal Chueca
# 478 - Best Western Los Condes
# 479 - Miau
# 480 - Petit Palace Cliper Gran Vía
# 481 - Holiday Inn Madrid-Pirámides
# 482 - Regente
# 483 - Hotel Puerta de Toledo Madrid
# 484 - Príncipe Pío
# 485 - Ibis Styles Madrid Prado
# 486 - Petit Palace Tres Cruces
# 487 - Petit Palace Puerta del Sol
# 488 - Petit Palace Preciados
# 489 - Petit Palace Triball
# 490 - Petit Palace Arenal
# 491 - Regina
# 492 - Room Mate Alicia
# 493 - Señorial
# 494 - Tryp Madrid Chamberí
# 495 - Victoria 4
# 496 - Hotel Madrid Centro
# 497 - Infanta Mercedes
# 498 - Hotel Madrid Gran Vía
# 499 - Tryp Madrid Chamartín
# 500 - Cortezo
# 501 - Travelodge Torrelaguna
# 502 - Silken Torre Garden
# 503 - Osuna
# 504 - Ópera
# 505 - Rafael Hoteles Ventas
# 506 - Atlántico
# 507 - Hotel Trafalgar
# 508 - Hotel Avenida Gran Vía
# 509 - Eurostars Zarzuela Park
# 510 - Dos Castillas
# 511 - Claridge
# 512 - Hrc-hotel
# 513 - Casón del Tormes
# 514 - Ateneo
# 515 - Anaco
# 516 - Acis y Galatea
# 517 - NH Zurbano
# 518 - NH Atocha
# 519 -  NH Madrid Sur
# 520 - NH Lagasca
# 521 - NH Madrid Chamberí
# 522 - NH Madrid Balboa
# 523 - Leonardo Boutique Hotel Madrid
# 524 - Leonardo Hotel Madrid City Center
# 525 - AC Avenida de América
# 526 - Hotel Villa de Barajas
# 527 - Preciados
# 528 - Quinta de los Cedros
# 529 - Suite Prado
# 530 - Tryp Alameda Aeropuerto
# 531 - Sercotel Alcalá 611
# 532 - Hotel Madrid Plaza España
# 533 - Villamadrid
# 534 - Vincci Vía 66
# 535 - Vincci Soho
# 536 - AC Coslada Aeropuerto
# 537 - Agumar
# 538 - Artiem Madrid
# 539 - Exe El Coloso
# 540 - Zenit Conde de Orgaz
# 541 - Don Pío
# 542 - Sercotel Eurobuilding 2
# 543 - Hotel City House Florida Norte
# 544 - NYX Madrid
# 545 - Gran Versalles
# 546 - VP Jardín de Recoletos
# 547 - Zenit Abeba
# 548 - Hotel Meninas
# 549 - Hotel Via Castellana
# 550 - Rafael Hoteles Atocha
# 551 - TRYP Madrid Atocha
# 552 - H10 Tribeca
# 553 - Petit Palace Plaza del Carmen
# 554 - Vincci Centrum Madrid
# 555 - Vincci Capitol
# 556 - Innside Madrid Gran Vía
# 557 - Gran Meliá Palacio de los Duques
# 558 - Mercure Madrid Plaza de España
# 559 - Pullman Madrid Airport & Feria
# 560 - Silken Puerta Madrid
# 561 - Exe Puerta Castilla
# 562 - Siete Islas Hotel
# 563 - Senator Gran Vía 70 Spa
# 564 - Quatro Puerta del Sol
# 565 - Praga
# 566 - Petit Palace Plaza de España
# 567 - Petit Palace Posada del Peine
# 568 - Meliá Madrid Serrano
# 569 - NH Collection Madrid Abascal
# 570 - H10 Puerta de Alcalá
# 571 - Petit Palace Alcalá Torre
# 572 - Icon Wipton by Petit Palace
# 573 - Palacio de San Martín
# 574 - NH La Habana
# 575 - Nuevo Madrid
# 576 - Exe Madrid Norte
# 577 - Ibis Styles Madrid City Las Ventas
# 578 - Novotel Madrid Campo de las Naciones
# 579 - NH Príncipe de Vergara
# 580 - NH Madrid Ventas
# 581 - NH Madrid Nacional
# 582 - Mercader
# 583 - Hotel NH Collection Madrid Colón
# 584 - Petit Palace Embassy
# 585 - NH Collection Madrid Eurobuilding
# 586 - Barceló Emperatriz
# 587 - Meliá Barajas
# 588 - Meliá Avenida América
# 589 - Me Madrid Reina Victoria
# 590 - Hotel Mayorazgo
# 591 - Eurostars Casa de la Lírica
# 592 - Lusso Infantas
# 593 - Liabeny
# 594 - Iberostar Las Letras Gran Vía
# 595 - Hotel Emperador
# 596 - Ilunion hotels Suites Madrid
# 597 - Hotel Weare Chamartín
# 598 - Hotel Paseo del Arte
# 599 - Hotel Serrano
# 600 - VP Jardín Metropolitano
# 601 - Mercure Madrid Centro (Lope de Vega)
# 602 - Clement Barajas
# 603 - AC Carlton
# 604 - Catalonia Goya
# 605 - Catalonia Las Cortes
# 606 - Catalonia Puerta del Sol
# 607 - Ayre Gran Hotel Colón
# 608 - Catalonia Gran Vía
# 609 - Sercotel Madrid Aeropuerto
# 610 - Sercotel Gran Hotel Conde Duque
# 611 - Bless Hotel Madrid
# 612 - H10 Villa de la Reina
# 613 - Petit Palace Arturo Soria
# 614 - Holiday Inn Madrid - Las Tablas
# 615 - Abba Madrid
# 616 - Petit Palace President Castellana
# 617 - Madrid Marriott Auditorium
# 618 - Hotel Occidental Madrid Este
# 619 - Ilunion Hotels Alcalá Norte
# 620 - Ilunion Pío XII
# 621 - NH Collection Madrid Paseo del Prado
# 622 - Hotel Santo Mauro, Autograph Collection
# 623 - Hotel Palacio del Retiro, Autograph Collection
# 624 - Monte Real
# 625 - Hyatt Regency Hesperia Madrid
# 626 - Eurostars Suites Mirasierra
# 627 - Gran Meliá Fénix
# 628 - Hotel Wellington
# 629 - AC Aitana
# 630 - Meliá Madrid Princesa
# 631 - Meliá Castilla
# 632 - InterContinental Madrid
# 633 - Princesa Plaza Madrid
# 634 - Orfila
# 635 - Mandarin Oriental Ritz
# 636 - Hotel Miguel Ángel
# 637 - The Westin Palace
# 638 - Hotel Urban 5*GL
# 639 - Vincci SoMa
# 640 - AC Recoletos
# 641 - AC Los Vascos
# 642 -  AC Hotel Madrid Feria
# 643 - Villa Real
# 644 - AC Hotel Cuzco
# 645 - AC Aravaca
# 646 - Puerta América
# Seleccione un alojamiento (0 -> Salir): 0

# %% [markdown]
# __Ejercicio 2 [3 puntos]__
#
# Este ejercicio se pide crear un buscador sobre la información recuperada, de forma que el usuario podrá buscar alojamientos por diferentes criterios:
#
#  * Tipo de alojamiento
#
#  * Estrellas
#
# Como resultado debería mostrarse un listado de todas los alojamientoss que cumplen las condiciones impuestas por el usuario. Se mostrará los nombres de los alojamientos. A continuación el usuario elegirá uno de los alojamientos y entonces se le mostrará  la misma información del alojamiento que en el ejercicio 1.  En caso de no existir un alojamiento con las condiciones dada, se mostrará un mensaje informativo.
#
# Observar que habrá que preguntar al usuario por cada uno de los criterios, y éste tendrá que seleccionar un valor por cada criterio o no seleccionarlo. Después de mostrarle la información, se le volverá a preguntar si quiere seguir buscando. Entre las opciones del menú deberá existir una que sea para finalizar la búsqueda.

# %% [markdown]
# Solución:

# %%
def filtrarPorAlojamiento(lista, filtroCat, raizArbol):  #función que filtra los alojamientos por una categoría dada
  lista2 = list()
  for alojamiento in lista:
    if get_Info(alojamiento, raizArbol)[0]['categoria'] == filtroCat:
      lista2.append(alojamiento)
  return lista2

def filtrarPorEstrellas(lista, filtroEstr, raizArbol): # función que filtra los alojamientos por unas estrellas dadas
  lista2 = list()
  for alojamiento in lista:
    if get_Info(alojamiento, raizArbol)[0]['estrellas'] == filtroEstr:
      lista2.append(alojamiento)
  return lista2
  
def func2(): #función con la lógica del ejercicio
  #listas que se usarás para mostrar los tipos de alojamientos y estrellas
  categoriasAlojamientos = list()
  tiposEstrellas = ["1 estrella","2 estrellas","3 estrellas","4 estrellas","5 estrellas", "No usar filtro"]

  raiz=arbol.getroot()
  #obtenemos la categoría del primer alojamiento
  info1 = get_Info(lista_alojamientos[0], raiz)
  categoria1 = info1[0]['categoria']
  categoriasAlojamientos.append(categoria1)

  #vamos añadiendo las categorías (sin repetirlas) en la lista de categorías
  for k in lista_alojamientos:
    infoAlojamiento = get_Info(k, raiz)
    if infoAlojamiento[0]['categoria'] not in categoriasAlojamientos and infoAlojamiento[0]['categoria'] != 'None':  
      categoriasAlojamientos.append(infoAlojamiento[0]['categoria'])

  categoriasAlojamientos.append('No usar filtro') #opción para no usar el filtro

  print("Buscador")

  #menú de categorías (tipos de alojamientos)
  print("Filtrar por tipo de alojamiento")
  cont = 1
  for categ in categoriasAlojamientos:
    print(cont, '-', categ)
    cont = cont + 1
  #elección del usuario
  filtroAlojamiento = int(input()) - 1
  print("Has elegido: ", categoriasAlojamientos[filtroAlojamiento])

  #menú de estrellas
  print("Filtrar por valoración(estrellas)")
  cont = 1
  for estr in tiposEstrellas:
    print(cont, '-', estr)
    cont = cont + 1
  #elección del usuario
  filtroEstrellas = int(input()) - 1
  print("Has elegido: ", tiposEstrellas[filtroEstrellas])

  if categoriasAlojamientos[filtroAlojamiento] == 'No usar filtro' and tiposEstrellas[filtroEstrellas] == 'No usar filtro':
    listafiltrada = lista_alojamientos #caso de que no se usen filtros. La lista no cambia, se mostrarán todos
  elif categoriasAlojamientos[filtroAlojamiento] == 'No usar filtro': #caso de que solo filtramos por estrellas. 
    listafiltrada = filtrarPorEstrellas(lista_alojamientos, tiposEstrellas[filtroEstrellas], raiz) #LLamamos a la función que devuelve una lista con los alojamiento que cumplen el filtro
  elif tiposEstrellas[filtroEstrellas] == 'No usar filtro': #caso de que solo filtramos por alojamiento
    listafiltrada = filtrarPorAlojamiento(lista_alojamientos, categoriasAlojamientos[filtroAlojamiento], raiz) #LLamamos a la función que devuelve una lista con los alojamiento que cumplen el filtro
  else: # caso en el que se usan los dos filtros
    listafiltrada1 = filtrarPorAlojamiento(lista_alojamientos, categoriasAlojamientos[filtroAlojamiento], raiz) #filtramos por alojamientos y devuelve una lista
    listafiltrada = filtrarPorEstrellas(listafiltrada1, tiposEstrellas[filtroEstrellas], raiz) # filtramos por estrellas la lista antes filtrada y devuelve la lista final
  
  return listafiltrada

# %%
listaConsulta2 = list()
listaConsulta2 = func2() #lista de alojamientos filtrada

if len(listaConsulta2) == 0: #si la lista es vacía es que no hay alojamientos para el filtro usado por el usuario
  print("No existen alojamientos para esos filtros")
else:
  func1(listaConsulta2) #llamamos a la función con la lógica del ejercicio 1, pasándole la lista filtrada

#una vez no quiera ver más alojamientos de la búsqueda, se le preguntará si quiere realizar una nueva búsqueda
busqueda = input("¿Desea hacer otra búsqueda? (s/n): ").lower()

while busqueda == "s": #mientras el usuario quiera hacer más búsquedas, repetimos lo anterior
  listaConsulta2 = list()
  listaConsulta2 = func2()

  if len(listaConsulta2) == 0:
    print("No existen alojamientos para esos filtros")
  else:
    func1(listaConsulta2)

  busqueda = input("¿Desea hacer otra búsqueda? (s/n): ").lower()

# %% [markdown]
# ### __Ejercicio 3[2 puntos]__
#
# Este ejercicio se pide crear un buscador de alojamiento por cercania a una calle indicada por el usuario. Para ello se usará la librería GeoPy que se usó en la práctica 2 y la información de latitud y longitud que aparece en el archivo xml de cada uno de los alojamientos. Se le preguntará al usuario que introduzca por teclado el nombre de la calle, el número y el código postal, y la distancia en kilómetros de cercania.
#
# Como resultado debería mostrarse un listado de todas los alojamientoss que cumplen las condiciones impuestas por el usuario. Se mostrará los nombres de los alojamientos. A continuación el usuario elegirá uno de los alojamientos y entonces se le mostrará  la misma información del alojamiento que en el ejercicio 1.  En caso de no existir una alojamiento con las condiciones dada, se mostrará un mensaje informativo.
#
#  Después de mostrarle la información, se le volverá a preguntar si quiere seguir buscando. Entre las opciones del menú deberá existir una que sea para finalizar la búsqueda.

# %% [markdown]
# Solución:

# %%
import geopy
from math import radians, cos, sin, asin, sqrt
def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    # Radius of earth in kilometers is 6371
    km = 6371* c
    return km

def longitudLatitud(i): #Funcion para calcular la longitud y latitud de un diccionario dado
  geolocator = geopy.Nominatim(user_agent="Ejemplo")
  location = geolocator.geocode(query={'street': i['NUM'] + " " + i['NOMBRE-VIA'],'postalcode':i['CODIGO-POSTAL']}, addressdetails=True)
  return (location.longitude, location.latitude)

def func3():
  contador = 1
  calleUsuario = input("Introduce el nombre de la calle: ")
  numeroUsuario = input("Introduce el numero: ")
  postalUsuario = input("Introduce el codigo postal: ")
  distanciaUsuario = float(input("Introduce la distancia en km de cercania: "))
  longLatUsuario = longitudLatitud({'NUM' : numeroUsuario, 'NOMBRE-VIA' : calleUsuario, 'CODIGO-POSTAL': postalUsuario})
  longUsuario = longLatUsuario[0]
  latUsuario = longLatUsuario[1]

  root=arbol.getroot()
  lista_alojamientos_distancia = list()
  i = 0
  for alojamiento in lista_alojamientos: #por cada alojamiento calculamos su distancia con la ubicacion introducida por el usuario
    info_alojamiento=get_Info(lista_alojamientos[i], root)
    longAlojamiento = float(info_alojamiento[0]['longitude'])
    latAlojamiento = float(info_alojamiento[0]['latitude'])
    if haversine(longUsuario, latUsuario, longAlojamiento, latAlojamiento) <= distanciaUsuario: #si la distancia esta dentro del rango del usuario
      lista_alojamientos_distancia.append(info_alojamiento[0]['name'])
    i += 1
  func1(lista_alojamientos_distancia)

# %%
func3()

# %% [markdown]
# Normas de entrega
#
#    * Fecha tope de entrega: 07/10/2021
#    * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosII_GrupoX donde X será el número de grupo correspondiente.

# %%
import html
html.umescape(cadena) #para quitar acentos ñ y cosas asi
